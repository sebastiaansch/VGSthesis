# %%
import sys
sys.path.append("../")
import nltk
import pandas as pd
import numpy as np
from helper import tokenize, dicttodf
import json
from nltk.tokenize import RegexpTokenizer
import shutil
import os

# %%
path = "/Users/sebastiaanscholten/Documents/speech2image-master/vgsexperiments/experiments/data/Flickr8k_text/Flickr8k.token.txt"

# %%
path2 = "/Users/sebastiaanscholten/Documents/speech2image-master/vgsexperiments/experiments/data/dataset.json"
file = json.load(open(path2))
split_dict = {}
for x in file['images']:
    split_dict[x['filename'].replace('.jpg', '')] = x['split']

# %%
testset = []
for key, value in split_dict.items():
    if value == "test":
        testset.append(key)

# %%
text = pd.read_csv(path, sep="\t",header=None)
text.columns = ["images","captions"]
textcopy = text
text.images = [words[:-6] for words in text.images if words==words]
text = text[text.images.isin(testset)]
text
# Out:
#                       images  \
# 210    1056338697_4f7d7ce270
# 211    1056338697_4f7d7ce270
# 212    1056338697_4f7d7ce270
# 213    1056338697_4f7d7ce270
# 214    1056338697_4f7d7ce270
# ...                      ...
# 40455   997722733_0cb5439472
# 40456   997722733_0cb5439472
# 40457   997722733_0cb5439472
# 40458   997722733_0cb5439472
# 40459   997722733_0cb5439472
#
#                                                 captions
# 210    A blond woman in a blue shirt appears to wait ...
# 211      A blond woman is on the street hailing a taxi .
# 212    A woman is signaling is to traffic , as seen f...
# 213    A woman with blonde hair wearing a blue tube t...
# 214    The woman in the blue dress is holding out her...
# ...                                                  ...
# 40455           A man in a pink shirt climbs a rock face
# 40456           A man is rock climbing high in the air .
# 40457  A person in a red shirt climbing up a rock fac...
# 40458                    A rock climber in a red shirt .
# 40459  A rock climber practices on a rock climbing wa...
#
# [5000 rows x 2 columns]

# %%
text = text["captions"]
tokenizer = RegexpTokenizer(r'\w+')
wordlist = []
for sentence in text:
    sentence = sentence.lower()
    words = tokenizer.tokenize(sentence)
    wordlist.extend(words)
wordlist = [x.lower() for x in wordlist]
sr = pd.Series(wordlist)
worddictionary = dict(sr.value_counts())

# %%
worddictionary
# Out:
# {'a': 7823,
#  'the': 2383,
#  'in': 2319,
#  'on': 1386,
#  'is': 1183,
#  'and': 1044,
#  'with': 973,
#  'dog': 953,
#  'man': 933,
#  'of': 811,
#  'two': 696,
#  'white': 528,
#  'boy': 507,
#  'black': 479,
#  'are': 456,
#  'girl': 427,
#  'wearing': 388,
#  'woman': 388,
#  'to': 383,
#  'at': 374,
#  'water': 352,
#  'people': 341,
#  'red': 339,
#  'young': 328,
#  'his': 325,
#  'blue': 303,
#  'an': 295,
#  'playing': 278,
#  'while': 264,
#  'dogs': 263,
#  'brown': 256,
#  'little': 255,
#  'shirt': 240,
#  'standing': 238,
#  'through': 237,
#  'down': 226,
#  'running': 220,
#  'child': 214,
#  'ball': 209,
#  'person': 198,
#  'front': 192,
#  'grass': 188,
#  'over': 186,
#  'small': 185,
#  'jumping': 181,
#  'beach': 174,
#  'up': 172,
#  'sitting': 169,
#  'holding': 169,
#  'three': 163,
#  'snow': 160,
#  'by': 159,
#  'her': 159,
#  'green': 153,
#  'one': 149,
#  'walking': 149,
#  'large': 148,
#  'into': 148,
#  'air': 145,
#  'group': 142,
#  'near': 140,
#  'yellow': 139,
#  'children': 137,
#  'field': 135,
#  'men': 131,
#  'street': 122,
#  'jumps': 121,
#  'another': 119,
#  'as': 118,
#  'stands': 116,
#  'mouth': 113,
#  'dirt': 111,
#  'girls': 108,
#  'for': 107,
#  'rock': 103,
#  'bike': 103,
#  'camera': 102,
#  'off': 101,
#  'orange': 100,
#  'out': 100,
#  'its': 99,
#  'from': 99,
#  'next': 96,
#  'riding': 96,
#  'mountain': 94,
#  'boys': 87,
#  'play': 87,
#  'looking': 87,
#  'pool': 86,
#  'hat': 86,
#  'other': 86,
#  'crowd': 83,
#  'pink': 82,
#  'player': 82,
#  'some': 81,
#  'women': 81,
#  'runs': 80,
#  'outside': 79,
#  'jacket': 79,
#  'plays': 78,
#  'ocean': 77,
#  'around': 75,
#  'basketball': 74,
#  'dressed': 74,
#  'looks': 73,
#  'walks': 72,
#  'background': 69,
#  'along': 68,
#  'sand': 68,
#  'swing': 67,
#  'building': 67,
#  'car': 66,
#  'rides': 65,
#  'has': 65,
#  'climbing': 65,
#  's': 65,
#  'behind': 64,
#  'wall': 64,
#  'doing': 64,
#  'sits': 64,
#  'their': 63,
#  'soccer': 62,
#  'holds': 62,
#  'hair': 61,
#  'smiling': 61,
#  'across': 60,
#  'back': 60,
#  'football': 57,
#  'together': 57,
#  'it': 56,
#  'sunglasses': 56,
#  'park': 55,
#  'grassy': 54,
#  'face': 54,
#  'head': 54,
#  'shorts': 54,
#  'dress': 53,
#  'table': 52,
#  'him': 52,
#  'stand': 51,
#  'that': 50,
#  'hand': 49,
#  'being': 49,
#  'tree': 49,
#  'hill': 49,
#  'swimming': 49,
#  'baby': 48,
#  'top': 48,
#  'lake': 48,
#  'dark': 48,
#  'picture': 48,
#  'snowy': 47,
#  'wave': 47,
#  'toy': 47,
#  'beside': 47,
#  'run': 46,
#  'tennis': 46,
#  'each': 46,
#  'tan': 45,
#  'there': 45,
#  'river': 45,
#  'bicycle': 45,
#  'frisbee': 45,
#  'carrying': 44,
#  'posing': 44,
#  'covered': 44,
#  'catch': 44,
#  'towards': 44,
#  'area': 44,
#  'city': 44,
#  'snowboarder': 43,
#  'sit': 42,
#  'race': 42,
#  'game': 42,
#  'stick': 42,
#  'jump': 42,
#  'something': 42,
#  'bench': 42,
#  'skateboard': 41,
#  'rocks': 41,
#  'ground': 41,
#  'surfer': 41,
#  'team': 41,
#  'road': 40,
#  'long': 40,
#  'path': 39,
#  'wooden': 39,
#  'rocky': 39,
#  'track': 38,
#  'trick': 38,
#  'purple': 38,
#  'ramp': 38,
#  'four': 37,
#  'several': 36,
#  'playground': 36,
#  'skateboarder': 36,
#  'sidewalk': 36,
#  'boat': 36,
#  'look': 35,
#  'helmet': 35,
#  'smiles': 35,
#  'kids': 35,
#  'older': 35,
#  'uniform': 35,
#  'hands': 34,
#  'them': 34,
#  'slide': 33,
#  'big': 33,
#  'watches': 32,
#  'grey': 32,
#  'striped': 32,
#  'players': 32,
#  'lady': 32,
#  'fence': 32,
#  'walk': 31,
#  'climbs': 31,
#  'watch': 31,
#  'under': 31,
#  'couple': 31,
#  'coat': 31,
#  'baseball': 30,
#  'mountains': 30,
#  'sign': 30,
#  'dancing': 30,
#  'side': 30,
#  'motorcycle': 30,
#  'leaps': 29,
#  'performing': 29,
#  'wet': 29,
#  'skier': 29,
#  'shore': 29,
#  'against': 28,
#  'rope': 28,
#  'all': 28,
#  'high': 28,
#  'midair': 28,
#  'rider': 28,
#  'floor': 27,
#  'suit': 27,
#  'outfit': 27,
#  'outdoor': 26,
#  'sweater': 26,
#  'taking': 26,
#  'outdoors': 26,
#  'he': 26,
#  'watching': 26,
#  'colored': 26,
#  'swinging': 26,
#  'someone': 26,
#  'pants': 26,
#  'above': 26,
#  'waves': 25,
#  'arms': 25,
#  'steps': 25,
#  'gray': 25,
#  'ride': 25,
#  'glasses': 25,
#  'ice': 25,
#  'toddler': 25,
#  'day': 25,
#  'biker': 24,
#  'body': 24,
#  'light': 24,
#  'trees': 24,
#  'getting': 24,
#  'leaves': 24,
#  'brick': 24,
#  'hanging': 24,
#  'horse': 24,
#  'who': 24,
#  'sky': 24,
#  'she': 23,
#  'number': 23,
#  'does': 23,
#  'eating': 23,
#  'sunset': 23,
#  'legs': 23,
#  'surfboard': 23,
#  'fountain': 23,
#  'colorful': 23,
#  'blonde': 23,
#  'takes': 22,
#  'racing': 22,
#  'bat': 22,
#  'cap': 22,
#  'jeans': 22,
#  'trail': 22,
#  'flying': 22,
#  'onto': 22,
#  'collar': 22,
#  'naked': 22,
#  'trunks': 21,
#  'tall': 21,
#  'scarf': 21,
#  'leaping': 21,
#  'during': 21,
#  'toward': 21,
#  'pulling': 21,
#  'away': 21,
#  'talking': 21,
#  'making': 21,
#  'blond': 21,
#  'yard': 21,
#  'skiing': 20,
#  'fighting': 20,
#  'board': 20,
#  'trying': 20,
#  'woods': 20,
#  'others': 20,
#  'line': 20,
#  'flip': 20,
#  'sled': 20,
#  'splashing': 20,
#  'haired': 20,
#  'room': 19,
#  'trampoline': 19,
#  'object': 19,
#  'edge': 19,
#  'five': 19,
#  'stream': 19,
#  'kid': 19,
#  'swings': 19,
#  'pose': 19,
#  'poses': 19,
#  'clothing': 18,
#  'shirtless': 18,
#  'guitar': 18,
#  'climber': 18,
#  'obstacle': 18,
#  'house': 18,
#  'adult': 18,
#  'pond': 18,
#  'after': 18,
#  'balls': 18,
#  'shallow': 18,
#  'cliff': 18,
#  'surfing': 18,
#  'leash': 17,
#  'tube': 17,
#  'cart': 17,
#  'bathing': 17,
#  'train': 17,
#  'catches': 17,
#  'arm': 17,
#  'fishing': 17,
#  't': 17,
#  'nearby': 17,
#  'inside': 17,
#  'ready': 17,
#  'open': 17,
#  'this': 17,
#  'about': 17,
#  'flowers': 17,
#  'uniforms': 17,
#  'drum': 17,
#  'bridge': 16,
#  'forest': 16,
#  'photo': 16,
#  'jersey': 16,
#  'dock': 16,
#  'many': 16,
#  'lawn': 16,
#  'picnic': 16,
#  'distance': 16,
#  'middle': 16,
#  'tire': 16,
#  'reading': 16,
#  'flies': 16,
#  'pole': 16,
#  'laughing': 16,
#  'lying': 16,
#  'costume': 16,
#  'skis': 16,
#  'going': 16,
#  'hockey': 16,
#  'shopping': 16,
#  'asian': 16,
#  'upside': 16,
#  'catching': 15,
#  'flag': 15,
#  'laying': 15,
#  'pointing': 15,
#  'slides': 15,
#  'wears': 15,
#  'whilst': 15,
#  'bird': 15,
#  'puppy': 15,
#  'golden': 15,
#  'very': 15,
#  'chasing': 15,
#  'stairs': 14,
#  'animal': 14,
#  'male': 14,
#  'six': 14,
#  'vest': 14,
#  'wading': 14,
#  'shot': 14,
#  'chases': 14,
#  'rail': 14,
#  'points': 14,
#  'gets': 14,
#  'or': 14,
#  'ski': 14,
#  'clothes': 14,
#  'waterfall': 14,
#  'backpack': 14,
#  'sliding': 14,
#  'surrounded': 13,
#  'paper': 13,
#  'setting': 13,
#  'bucket': 13,
#  'between': 13,
#  'kick': 13,
#  'feet': 13,
#  'stunt': 13,
#  'buildings': 13,
#  'right': 13,
#  'bar': 13,
#  'shirts': 13,
#  'steep': 13,
#  'sports': 13,
#  'equipment': 13,
#  'harness': 13,
#  'winter': 13,
#  'bag': 13,
#  'costumes': 13,
#  'set': 13,
#  'waiting': 13,
#  'swimsuit': 13,
#  'tries': 13,
#  'restaurant': 13,
#  'bright': 13,
#  'bubbles': 13,
#  'backyard': 13,
#  'railing': 12,
#  'snowboard': 12,
#  'shoes': 12,
#  'coming': 12,
#  'tricks': 12,
#  'paddling': 12,
#  'hurdle': 12,
#  'facing': 12,
#  'hiker': 12,
#  'nose': 12,
#  'kicking': 12,
#  'faces': 12,
#  'deep': 12,
#  'dance': 12,
#  'like': 12,
#  'handstand': 12,
#  'plastic': 12,
#  'guy': 12,
#  'motocross': 12,
#  'sweatshirt': 12,
#  'past': 12,
#  'goal': 12,
#  'gloves': 12,
#  'metal': 12,
#  'course': 12,
#  'life': 12,
#  'lone': 12,
#  'leg': 12,
#  'sandy': 11,
#  'ladder': 11,
#  'performs': 11,
#  'fight': 11,
#  'stage': 11,
#  'smile': 11,
#  'lot': 11,
#  'held': 11,
#  'free': 11,
#  'sun': 11,
#  'gym': 11,
#  'tents': 11,
#  'bank': 11,
#  'sunny': 11,
#  'rowing': 11,
#  'bikes': 11,
#  'night': 11,
#  'they': 11,
#  'skateboarding': 11,
#  'diving': 11,
#  'empty': 11,
#  'pictures': 11,
#  'smaller': 11,
#  'swims': 11,
#  'sprinkler': 11,
#  'canoe': 11,
#  'cross': 11,
#  'sticks': 11,
#  'airborne': 11,
#  'old': 11,
#  'cellphone': 11,
#  'hit': 10,
#  'food': 10,
#  'boxing': 10,
#  'says': 10,
#  'hind': 10,
#  'family': 10,
#  'stone': 10,
#  'coach': 10,
#  'fluffy': 10,
#  'climb': 10,
#  'kissing': 10,
#  'full': 10,
#  'corner': 10,
#  'greyhound': 10,
#  'wood': 10,
#  'driving': 10,
#  'no': 10,
#  'rugby': 10,
#  'martial': 10,
#  'different': 10,
#  'which': 10,
#  'paint': 10,
#  'statue': 10,
#  'staircase': 10,
#  'overlooking': 10,
#  'makes': 10,
#  'sprayed': 10,
#  'silver': 10,
#  'busy': 10,
#  'kicks': 10,
#  'dresses': 10,
#  'bed': 10,
#  'follows': 10,
#  'have': 10,
#  'thrown': 10,
#  'go': 10,
#  'hugs': 10,
#  'bmx': 10,
#  'rolling': 9,
#  'puts': 9,
#  'sniffing': 9,
#  'wheelie': 9,
#  'kiddie': 9,
#  'parking': 9,
#  'surface': 9,
#  'beige': 9,
#  'mud': 9,
#  'same': 9,
#  'eyes': 9,
#  'gathered': 9,
#  'box': 9,
#  'mask': 9,
#  'foreground': 9,
#  'stroller': 9,
#  'drives': 9,
#  'tongue': 9,
#  'gravel': 9,
#  'karate': 9,
#  'wooded': 9,
#  'adults': 9,
#  'shadow': 9,
#  'competition': 9,
#  'low': 9,
#  'helps': 9,
#  'carries': 9,
#  'swim': 9,
#  'vehicle': 9,
#  'get': 9,
#  'backwards': 9,
#  'fallen': 9,
#  'jackets': 9,
#  'drink': 9,
#  'huge': 9,
#  'seat': 9,
#  'outfits': 9,
#  'sleeping': 9,
#  'concrete': 9,
#  'fire': 9,
#  'leans': 9,
#  'cement': 9,
#  'cow': 9,
#  'smoking': 8,
#  'graffiti': 8,
#  'subway': 8,
#  'hangs': 8,
#  'left': 8,
#  'cyclist': 8,
#  'biting': 8,
#  'dribbles': 8,
#  'wetsuit': 8,
#  'lit': 8,
#  'blows': 8,
#  'both': 8,
#  'crowded': 8,
#  'splashes': 8,
#  'drinking': 8,
#  'seated': 8,
#  'wheel': 8,
#  'fenced': 8,
#  'talks': 8,
#  'police': 8,
#  'make': 8,
#  'round': 8,
#  'pile': 8,
#  'closeup': 8,
#  'downhill': 8,
#  'porch': 8,
#  'lays': 8,
#  'jungle': 8,
#  'female': 8,
#  'newspaper': 8,
#  'skating': 8,
#  'teenage': 8,
#  'blocks': 8,
#  'ladies': 8,
#  'hiking': 8,
#  'arts': 8,
#  'surf': 8,
#  'splash': 8,
#  'tent': 8,
#  'softball': 8,
#  'bull': 8,
#  'clouds': 8,
#  'shoulders': 8,
#  'motorbike': 8,
#  'seats': 8,
#  'plants': 8,
#  'dances': 8,
#  'fair': 8,
#  'pack': 8,
#  'muzzle': 8,
#  'guys': 8,
#  'patio': 8,
#  'covering': 8,
#  'eats': 8,
#  'mother': 8,
#  'bunch': 8,
#  'goggles': 8,
#  'sooners': 7,
#  'break': 7,
#  'mirror': 7,
#  'skiers': 7,
#  'bars': 7,
#  'skinned': 7,
#  'rolls': 7,
#  'scooter': 7,
#  'rain': 7,
#  'races': 7,
#  'walkway': 7,
#  'pushes': 7,
#  'public': 7,
#  'shoulder': 7,
#  'bends': 7,
#  'court': 7,
#  'ring': 7,
#  'lights': 7,
#  'branch': 7,
#  'pulls': 7,
#  'blanket': 7,
#  'short': 7,
#  'store': 7,
#  'tail': 7,
#  'sparklers': 7,
#  'lies': 7,
#  'kayak': 7,
#  'preparing': 7,
#  'boots': 7,
#  'leaning': 7,
#  'structure': 7,
#  'painted': 7,
#  'golf': 7,
#  'necklace': 7,
#  'crossing': 7,
#  'few': 7,
#  'glass': 7,
#  'motorcyclist': 7,
#  'phone': 7,
#  'spinning': 7,
#  'traffic': 7,
#  'muzzled': 7,
#  'chair': 7,
#  'be': 7,
#  'moving': 7,
#  'bear': 7,
#  'gate': 7,
#  'reaches': 7,
#  'couch': 7,
#  'block': 7,
#  'raft': 7,
#  'throw': 7,
#  'lift': 7,
#  'slope': 7,
#  'lines': 7,
#  'book': 7,
#  'tunnel': 7,
#  'flowered': 7,
#  'painting': 7,
#  'onlookers': 7,
#  'streets': 7,
#  'base': 7,
#  'airplane': 7,
#  'tattoo': 7,
#  'attempting': 7,
#  'lap': 7,
#  'pier': 7,
#  'spectators': 7,
#  'pirate': 6,
#  'shoot': 6,
#  'dives': 6,
#  'whistle': 6,
#  'miami': 6,
#  'dust': 6,
#  'lined': 6,
#  'before': 6,
#  'plain': 6,
#  'below': 6,
#  'bending': 6,
#  'shakes': 6,
#  'poles': 6,
#  'headband': 6,
#  'chairs': 6,
#  'leading': 6,
#  'art': 6,
#  'examine': 6,
#  'pushing': 6,
#  'pipe': 6,
#  'way': 6,
#  'hoops': 6,
#  'beautiful': 6,
#  'ledge': 6,
#  'using': 6,
#  'log': 6,
#  'jet': 6,
#  'falling': 6,
#  'younger': 6,
#  'piece': 6,
#  'landscape': 6,
#  'fingers': 6,
#  'teams': 6,
#  'party': 6,
#  'window': 6,
#  'microphone': 6,
#  'balancing': 6,
#  'audience': 6,
#  'patch': 6,
#  'gather': 6,
#  'ears': 6,
#  'pavement': 6,
#  'finger': 6,
#  'skate': 6,
#  'station': 6,
#  'teal': 6,
#  'hoodie': 6,
#  'indoor': 6,
#  'scene': 6,
#  'puddle': 6,
#  'wide': 6,
#  'bags': 6,
#  'shaking': 6,
#  'part': 6,
#  'reaching': 6,
#  'indoors': 6,
#  'garden': 6,
#  'bikini': 6,
#  'practicing': 6,
#  'racetrack': 6,
#  'mouths': 6,
#  'circle': 6,
#  'teenagers': 6,
#  'helmeted': 6,
#  'homeless': 6,
#  'fast': 6,
#  'hillside': 6,
#  'living': 6,
#  'barefoot': 6,
#  'atop': 6,
#  'coffee': 6,
#  'having': 6,
#  'collie': 6,
#  'hose': 6,
#  'bouncing': 6,
#  'boxer': 6,
#  'flight': 6,
#  'racket': 6,
#  '5': 5,
#  'map': 5,
#  'pit': 5,
#  'sleeved': 5,
#  'bowling': 5,
#  'direction': 5,
#  'asleep': 5,
#  'wagon': 5,
#  'dry': 5,
#  'work': 5,
#  'single': 5,
#  'bandanna': 5,
#  'putting': 5,
#  'creek': 5,
#  'elderly': 5,
#  'gold': 5,
#  'pet': 5,
#  'outstretched': 5,
#  'parachute': 5,
#  'bites': 5,
#  'flower': 5,
#  'raised': 5,
#  'without': 5,
#  'parade': 5,
#  'neck': 5,
#  'indian': 5,
#  'fireworks': 5,
#  'talk': 5,
#  'underneath': 5,
#  'door': 5,
#  'cake': 5,
#  'hats': 5,
#  'pajamas': 5,
#  'bottom': 5,
#  'cardboard': 5,
#  'but': 5,
#  'dirty': 5,
#  'close': 5,
#  'corn': 5,
#  'clear': 5,
#  'quickly': 5,
#  'event': 5,
#  'fancy': 5,
#  'hitting': 5,
#  'wrestle': 5,
#  'these': 5,
#  'pumpkins': 5,
#  'appears': 5,
#  'made': 5,
#  'throws': 5,
#  'aerial': 5,
#  'neon': 5,
#  'skates': 5,
#  'reads': 5,
#  'fly': 5,
#  'attire': 5,
#  'moves': 5,
#  'writing': 5,
#  'atv': 5,
#  'bushes': 5,
#  'cowboy': 5,
#  'throwing': 5,
#  'monkey': 5,
#  'enjoying': 5,
#  'school': 5,
#  'drinks': 5,
#  'spoon': 5,
#  'resting': 5,
#  'puffy': 5,
#  'christmas': 5,
#  'crown': 5,
#  'pass': 5,
#  'formation': 5,
#  'milkshake': 5,
#  'fish': 5,
#  'row': 5,
#  'bay': 5,
#  'chip': 5,
#  'gear': 5,
#  'hold': 5,
#  'computer': 5,
#  'reach': 5,
#  'punching': 5,
#  'larger': 5,
#  'muddy': 5,
#  'horses': 5,
#  'courtyard': 5,
#  'counter': 5,
#  'african': 5,
#  'foot': 5,
#  'dribbling': 5,
#  'seen': 5,
#  'paintball': 5,
#  'students': 5,
#  'tourists': 5,
#  'sweaters': 5,
#  'goes': 5,
#  'band': 5,
#  'mohawk': 5,
#  'merry': 5,
#  'shoreline': 5,
#  'spots': 5,
#  'puppies': 5,
#  'shaggy': 5,
#  'deer': 5,
#  'casts': 5,
#  'where': 5,
#  'float': 5,
#  'cloudy': 5,
#  'take': 5,
#  'stadium': 5,
#  'wear': 5,
#  'kangaroo': 5,
#  'speaking': 5,
#  'half': 5,
#  'staring': 5,
#  'stop': 5,
#  'eat': 5,
#  'opposing': 5,
#  'cricket': 5,
#  'paws': 5,
#  'beard': 5,
#  'ridden': 5,
#  'waits': 5,
#  'stools': 5,
#  'blurry': 5,
#  'war': 5,
#  'string': 5,
#  'snake': 5,
#  'sport': 5,
#  'action': 5,
#  'filled': 5,
#  'twin': 5,
#  'inflatable': 5,
#  'chase': 5,
#  'suits': 5,
#  'alley': 5,
#  'chalk': 5,
#  'show': 5,
#  'sticking': 5,
#  'hits': 5,
#  'mound': 5,
#  'binoculars': 5,
#  'towel': 5,
#  'kiss': 5,
#  'terrain': 5,
#  'lands': 5,
#  'forward': 5,
#  'skateboards': 5,
#  'tug': 5,
#  'photograph': 5,
#  'fall': 5,
#  'so': 4,
#  'raises': 4,
#  'handrail': 4,
#  'butt': 4,
#  'firetruck': 4,
#  'human': 4,
#  'mountaintop': 4,
#  'gondola': 4,
#  'lane': 4,
#  'leather': 4,
#  'teacher': 4,
#  'handlebars': 4,
#  'scarves': 4,
#  'ear': 4,
#  'video': 4,
#  'amid': 4,
#  'spray': 4,
#  'referee': 4,
#  'laughs': 4,
#  'platform': 4,
#  'kneeling': 4,
#  'footprints': 4,
#  'funny': 4,
#  'natural': 4,
#  'vests': 4,
#  'japanese': 4,
#  'bundled': 4,
#  'waterskiing': 4,
#  'music': 4,
#  'cannon': 4,
#  'extended': 4,
#  'mexican': 4,
#  'meadow': 4,
#  'construction': 4,
#  'items': 4,
#  'baskets': 4,
#  'scales': 4,
#  'starting': 4,
#  'bottle': 4,
#  'words': 4,
#  'dumpster': 4,
#  'curly': 4,
#  'paddles': 4,
#  'plate': 4,
#  'unfinished': 4,
#  'opposite': 4,
#  'backs': 4,
#  'foam': 4,
#  'driveway': 4,
#  'pull': 4,
#  'following': 4,
#  'boogie': 4,
#  'leaving': 4,
#  'evening': 4,
#  'rafting': 4,
#  'surfs': 4,
#  'einstein': 4,
#  'daughter': 4,
#  'country': 4,
#  'whales': 4,
#  'stump': 4,
#  'runner': 4,
#  'begins': 4,
#  'square': 4,
#  'doll': 4,
#  'truck': 4,
#  'oriental': 4,
#  'skirt': 4,
#  'attempts': 4,
#  'skinny': 4,
#  'noodle': 4,
#  ...}

# %%
import nltk
postags = nltk.pos_tag(worddf["words"])

# %%
from helper import return_postag_keys

# %%
textcp = pd.read_csv(path, sep="\t",header=None)
textcp.columns = ["images","captions"]
textcp["original"] = textcp["images"]
textcp.images = [words[:-6] for words in textcp.images if words==words]
textcp = textcp[textcp.images.isin(testset)]
textcp = textcp.drop(columns = "images")
textcp
textcp.to_csv("textcp.csv",index=False)

# %%
def match_word_wavfile():
    inputword = input("Enter word here: ")
    wavfiles = []
    for idx, captions in enumerate(textcp.captions):
        if inputword in tokenizer.tokenize(captions):
            wavfiles.append(textcp.original.iloc[idx])
    wavfilenames = []
    for word in wavfiles:
        word = word.replace("#","_")
        word = word.replace(".jpg","")
        wavfilenames.append(word)
    return wavfilenames,inputword,wavfiles

# %%
wavfilenames,inputword,wavfiles = match_word_wavfile()
# Out:
# Enter word here: orange

# %%
len(wavfilenames)
# Out:
# 96

# %%
# def seperate_files_from_list(inputwords):
#     #loop through the words
#     for inputword in inputwords:
#         wavfiles = []
#         #find captions that contain these words
#         for idx, captions in enumerate(textcp.captions):
#             if inputword in tokenizer.tokenize(captions):
#                 wavfiles.append(textcp.original.iloc[idx])
#         wavfilenames = []
#         #preprocess them for file copying
#         for word in wavfiles:
#             word = word.replace("#","_")
#             word = word.replace(".jpg","")
#             wavfilenames.append(word)
#         count = 0
#         source = "/Volumes/Schnellheit/ThesisData/flickrwavsandimagestextandjson/flickr_audio/wavs/"
#         dest = "/Volumes/Schnellheit/ThesisData/flickrwavsandimagestextandjson/flickr_audio/" + inputword + "/"
#         #move the files
#         if not os.path.exists(dest):
#             os.mkdir(dest)
#         for word in wavfilenames:
#             count = count + 1
#             word = word + ".wav"
#             sourceword = source + word
#             worddest = dest + word
#             shutil.copy(sourceword,worddest)
#             if count == 50:
#                 count = 0
#                 break
# listtest = ["dog","man","boy","girl","woman","people"
#             ,"dogs","shirt","child","ball","person"
#             ,"children","men","girls","bike","rock","camera"
#             ,"boys","hat","player","jacket","basketball","swing"
#             ,"car", "wall", "hair","football","sunglasses","head"
#             ,"shorts","dress","table"]

# # seperate_files_from_list(listtest)

# %%
from collections import defaultdict
def print_file_list(inputwords):
    #loop through the words
    word_appended_finallist = []
    finallist = []
    finallistdict = defaultdict(list)
    for inputword in inputwords:
        wavfiles = []
        #find captions that contain these words
        for idx, captions in enumerate(textcp.captions):
            if inputword in tokenizer.tokenize(captions):
                wavfiles.append(textcp.original.iloc[idx])
        wavfilenames = []
        #preprocess them for file copying
        for word in wavfiles:
            word = word.replace("#","_")
            word = word.replace(".jpg","")
            wordwithinputword = inputword + "_" + word
            wavfilenames.append(word)
        count = 0
        #move the files
        for word in wavfilenames:
            count = count + 1
            word_appended_finallist.append(wordwithinputword)
            finallist.append(word)
            file = word.split('_', -1)[0:2]
            testword = "_".join(file)
            wordjpg = testword + ".jpg"
            finallistdict[wordjpg].append(inputword)
            if count == 50:
                count = 0
                break         
    return wavfiles,wavfilenames,word_appended_finallist,finallist,finallistdict

# %%
listtest2 = ["dog","man","boy","girl","woman","people"
            ,"dogs","shirt","child","ball","person"
            ,"children","men","girls","bike","rock","camera"
            ,"boys","hat","player","jacket","basketball","swing"
            ,"car", "wall", "hair","football","sunglasses","head"
            ,"shorts","dress","table","water","grass","bench","snow"
            ,"air","field","street","mouth","dirt","mountain","pool"
            ,"ocean","sand","building","soccer","park","face"]

# %%
wavfiles, wavfilenames,word_appended_finallist,finallist,finallistdict = print_file_list(listtest)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-38-06700d3db43a> in <module>
# ----> 1 wavfiles, wavfilenames,word_appended_finallist,finallist,finallistdict = print_file_list(listtest)
#
# NameError: name 'print_file_list' is not defined

# %%
word_appended_finallist = pd.DataFrame(word_appended_finallist)
word_appended_finallist.to_csv("word_appended_finallist.txt",index=False,header=False)

finallist = pd.DataFrame(finallist)
finallist.to_csv("finallist.txt",index=False,header=False)

# %%
finallistdict
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-8ebd396ac2e6> in <module>
# ----> 1 finallistdict
#
# NameError: name 'finallistdict' is not defined

# %%
finallistdict
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-39-425f6a66d731> in <module>
# ----> 1 len(finallistdict)
#
# NameError: name 'finallistdict' is not defined

# %%
#inefficient way to remove caption number from files for comparison
file = captionfile.split('_', -1)[0:2]
testword = "_".join(file)
# Out:
# '1267711451_e2a754b4f8'

# %%
with open('/Users/sebastiaanscholten/Documents/speech2image-master/vgsexperiments/experiments/data/finallistdict.json', 'w') as fp:
    json.dump(finallistdict, fp)

# %%
"hi_here_this".split("_",-1)[0]
# Out:
# 'hi'

# %%
import torch

# %%
x = torch.tensor([2,3,3])

# %%
x
# Out:
# pandas.core.frame.DataFrame

# %%
names = ["hey","yo"]
listtest = [[1,1,1,1,1],[1,1,1,1,0]]
listtest2 = [[1,1,1,1,1],[1,1,1,1,0]]

# %%
x = pd.DataFrame(names,lis)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-171-2053c5e4614b> in <module>
# ----> 1 x = pd.DataFrame(names,lis)
#
# NameError: name 'lis' is not defined

# %%
test = list(zip(names,listtest,listtest2))
k = pd.DataFrame(test,columns=["ok","d","s"])

# %%
import sys
sys.path.append("../")
import nltk
import pandas as pd
import numpy as np
from helper import tokenize, dicttodf
import json
from nltk.tokenize import RegexpTokenizer
import shutil
import os

# %%
path = "/Users/sebastiaanscholten/Documents/speech2image-master/vgsexperiments/experiments/data/Flickr8k_text/Flickr8k.token.txt"

# %%
path2 = "/Users/sebastiaanscholten/Documents/speech2image-master/vgsexperiments/experiments/data/dataset.json"
file = json.load(open(path2))
split_dict = {}
for x in file['images']:
    split_dict[x['filename'].replace('.jpg', '')] = x['split']

# %%
testset = []
for key, value in split_dict.items():
    if value == "test":
        testset.append(key)

# %%
text = pd.read_csv(path, sep="\t",header=None)
text.columns = ["images","captions"]
textcopy = text
text.images = [words[:-6] for words in text.images if words==words]
text = text[text.images.isin(testset)]
text
# Out:
#                       images  \
# 210    1056338697_4f7d7ce270
# 211    1056338697_4f7d7ce270
# 212    1056338697_4f7d7ce270
# 213    1056338697_4f7d7ce270
# 214    1056338697_4f7d7ce270
# ...                      ...
# 40455   997722733_0cb5439472
# 40456   997722733_0cb5439472
# 40457   997722733_0cb5439472
# 40458   997722733_0cb5439472
# 40459   997722733_0cb5439472
#
#                                                 captions
# 210    A blond woman in a blue shirt appears to wait ...
# 211      A blond woman is on the street hailing a taxi .
# 212    A woman is signaling is to traffic , as seen f...
# 213    A woman with blonde hair wearing a blue tube t...
# 214    The woman in the blue dress is holding out her...
# ...                                                  ...
# 40455           A man in a pink shirt climbs a rock face
# 40456           A man is rock climbing high in the air .
# 40457  A person in a red shirt climbing up a rock fac...
# 40458                    A rock climber in a red shirt .
# 40459  A rock climber practices on a rock climbing wa...
#
# [5000 rows x 2 columns]

# %%
text = text["captions"]
tokenizer = RegexpTokenizer(r'\w+')
wordlist = []
for sentence in text:
    sentence = sentence.lower()
    words = tokenizer.tokenize(sentence)
    wordlist.extend(words)
wordlist = [x.lower() for x in wordlist]
sr = pd.Series(wordlist)
worddictionary = dict(sr.value_counts())

# %%
worddictionary
# Out:
# {'a': 7823,
#  'the': 2383,
#  'in': 2319,
#  'on': 1386,
#  'is': 1183,
#  'and': 1044,
#  'with': 973,
#  'dog': 953,
#  'man': 933,
#  'of': 811,
#  'two': 696,
#  'white': 528,
#  'boy': 507,
#  'black': 479,
#  'are': 456,
#  'girl': 427,
#  'woman': 388,
#  'wearing': 388,
#  'to': 383,
#  'at': 374,
#  'water': 352,
#  'people': 341,
#  'red': 339,
#  'young': 328,
#  'his': 325,
#  'blue': 303,
#  'an': 295,
#  'playing': 278,
#  'while': 264,
#  'dogs': 263,
#  'brown': 256,
#  'little': 255,
#  'shirt': 240,
#  'standing': 238,
#  'through': 237,
#  'down': 226,
#  'running': 220,
#  'child': 214,
#  'ball': 209,
#  'person': 198,
#  'front': 192,
#  'grass': 188,
#  'over': 186,
#  'small': 185,
#  'jumping': 181,
#  'beach': 174,
#  'up': 172,
#  'holding': 169,
#  'sitting': 169,
#  'three': 163,
#  'snow': 160,
#  'her': 159,
#  'by': 159,
#  'green': 153,
#  'one': 149,
#  'walking': 149,
#  'into': 148,
#  'large': 148,
#  'air': 145,
#  'group': 142,
#  'near': 140,
#  'yellow': 139,
#  'children': 137,
#  'field': 135,
#  'men': 131,
#  'street': 122,
#  'jumps': 121,
#  'another': 119,
#  'as': 118,
#  'stands': 116,
#  'mouth': 113,
#  'dirt': 111,
#  'girls': 108,
#  'for': 107,
#  'rock': 103,
#  'bike': 103,
#  'camera': 102,
#  'off': 101,
#  'out': 100,
#  'orange': 100,
#  'from': 99,
#  'its': 99,
#  'next': 96,
#  'riding': 96,
#  'mountain': 94,
#  'looking': 87,
#  'boys': 87,
#  'play': 87,
#  'pool': 86,
#  'other': 86,
#  'hat': 86,
#  'crowd': 83,
#  'pink': 82,
#  'player': 82,
#  'some': 81,
#  'women': 81,
#  'runs': 80,
#  'outside': 79,
#  'jacket': 79,
#  'plays': 78,
#  'ocean': 77,
#  'around': 75,
#  'basketball': 74,
#  'dressed': 74,
#  'looks': 73,
#  'walks': 72,
#  'background': 69,
#  'sand': 68,
#  'along': 68,
#  'swing': 67,
#  'building': 67,
#  'car': 66,
#  'has': 65,
#  'rides': 65,
#  'climbing': 65,
#  's': 65,
#  'behind': 64,
#  'wall': 64,
#  'sits': 64,
#  'doing': 64,
#  'their': 63,
#  'holds': 62,
#  'soccer': 62,
#  'smiling': 61,
#  'hair': 61,
#  'across': 60,
#  'back': 60,
#  'football': 57,
#  'together': 57,
#  'it': 56,
#  'sunglasses': 56,
#  'park': 55,
#  'shorts': 54,
#  'face': 54,
#  'head': 54,
#  'grassy': 54,
#  'dress': 53,
#  'him': 52,
#  'table': 52,
#  'stand': 51,
#  'that': 50,
#  'swimming': 49,
#  'hand': 49,
#  'being': 49,
#  'tree': 49,
#  'hill': 49,
#  'baby': 48,
#  'top': 48,
#  'dark': 48,
#  'picture': 48,
#  'lake': 48,
#  'snowy': 47,
#  'toy': 47,
#  'wave': 47,
#  'beside': 47,
#  'run': 46,
#  'tennis': 46,
#  'each': 46,
#  'tan': 45,
#  'there': 45,
#  'bicycle': 45,
#  'frisbee': 45,
#  'river': 45,
#  'area': 44,
#  'covered': 44,
#  'posing': 44,
#  'city': 44,
#  'towards': 44,
#  'carrying': 44,
#  'catch': 44,
#  'snowboarder': 43,
#  'game': 42,
#  'jump': 42,
#  'something': 42,
#  'race': 42,
#  'bench': 42,
#  'stick': 42,
#  'sit': 42,
#  'surfer': 41,
#  'skateboard': 41,
#  'team': 41,
#  'ground': 41,
#  'rocks': 41,
#  'long': 40,
#  'road': 40,
#  'rocky': 39,
#  'path': 39,
#  'wooden': 39,
#  'track': 38,
#  'trick': 38,
#  'purple': 38,
#  'ramp': 38,
#  'four': 37,
#  'boat': 36,
#  'several': 36,
#  'playground': 36,
#  'skateboarder': 36,
#  'sidewalk': 36,
#  'kids': 35,
#  'uniform': 35,
#  'older': 35,
#  'helmet': 35,
#  'look': 35,
#  'smiles': 35,
#  'them': 34,
#  'hands': 34,
#  'big': 33,
#  'slide': 33,
#  'lady': 32,
#  'players': 32,
#  'watches': 32,
#  'fence': 32,
#  'striped': 32,
#  'grey': 32,
#  'watch': 31,
#  'couple': 31,
#  'climbs': 31,
#  'under': 31,
#  'walk': 31,
#  'coat': 31,
#  'sign': 30,
#  'dancing': 30,
#  'baseball': 30,
#  'motorcycle': 30,
#  'side': 30,
#  'mountains': 30,
#  'leaps': 29,
#  'performing': 29,
#  'shore': 29,
#  'skier': 29,
#  'wet': 29,
#  'midair': 28,
#  'all': 28,
#  'high': 28,
#  'rope': 28,
#  'against': 28,
#  'rider': 28,
#  'suit': 27,
#  'floor': 27,
#  'outfit': 27,
#  'watching': 26,
#  'he': 26,
#  'pants': 26,
#  'outdoor': 26,
#  'sweater': 26,
#  'above': 26,
#  'someone': 26,
#  'outdoors': 26,
#  'colored': 26,
#  'taking': 26,
#  'swinging': 26,
#  'glasses': 25,
#  'steps': 25,
#  'ice': 25,
#  'gray': 25,
#  'waves': 25,
#  'day': 25,
#  'ride': 25,
#  'toddler': 25,
#  'arms': 25,
#  'getting': 24,
#  'body': 24,
#  'sky': 24,
#  'brick': 24,
#  'leaves': 24,
#  'trees': 24,
#  'horse': 24,
#  'biker': 24,
#  'who': 24,
#  'light': 24,
#  'hanging': 24,
#  'colorful': 23,
#  'blonde': 23,
#  'number': 23,
#  'surfboard': 23,
#  'legs': 23,
#  'eating': 23,
#  'she': 23,
#  'sunset': 23,
#  'fountain': 23,
#  'does': 23,
#  'flying': 22,
#  'trail': 22,
#  'onto': 22,
#  'bat': 22,
#  'cap': 22,
#  'racing': 22,
#  'naked': 22,
#  'collar': 22,
#  'takes': 22,
#  'jeans': 22,
#  'toward': 21,
#  'away': 21,
#  'blond': 21,
#  'tall': 21,
#  'during': 21,
#  'pulling': 21,
#  'scarf': 21,
#  'trunks': 21,
#  'making': 21,
#  'yard': 21,
#  'leaping': 21,
#  'talking': 21,
#  'flip': 20,
#  'sled': 20,
#  'splashing': 20,
#  'fighting': 20,
#  'woods': 20,
#  'haired': 20,
#  'line': 20,
#  'trying': 20,
#  'board': 20,
#  'skiing': 20,
#  'others': 20,
#  'kid': 19,
#  'five': 19,
#  'stream': 19,
#  'room': 19,
#  'edge': 19,
#  'trampoline': 19,
#  'pose': 19,
#  'object': 19,
#  'poses': 19,
#  'swings': 19,
#  'surfing': 18,
#  'shallow': 18,
#  'guitar': 18,
#  'obstacle': 18,
#  'pond': 18,
#  'cliff': 18,
#  'clothing': 18,
#  'climber': 18,
#  'shirtless': 18,
#  'house': 18,
#  'balls': 18,
#  'adult': 18,
#  'after': 18,
#  'about': 17,
#  'uniforms': 17,
#  'arm': 17,
#  't': 17,
#  'this': 17,
#  'drum': 17,
#  'bathing': 17,
#  'flowers': 17,
#  'tube': 17,
#  'cart': 17,
#  'ready': 17,
#  'fishing': 17,
#  'inside': 17,
#  'catches': 17,
#  'open': 17,
#  'train': 17,
#  'nearby': 17,
#  'leash': 17,
#  'middle': 16,
#  'tire': 16,
#  'lying': 16,
#  'dock': 16,
#  'forest': 16,
#  'hockey': 16,
#  'pole': 16,
#  'shopping': 16,
#  'asian': 16,
#  'many': 16,
#  'flies': 16,
#  'costume': 16,
#  'upside': 16,
#  'distance': 16,
#  'jersey': 16,
#  'laughing': 16,
#  'reading': 16,
#  'skis': 16,
#  'going': 16,
#  'photo': 16,
#  'lawn': 16,
#  'picnic': 16,
#  'bridge': 16,
#  'pointing': 15,
#  'golden': 15,
#  'bird': 15,
#  'whilst': 15,
#  'chasing': 15,
#  'slides': 15,
#  'puppy': 15,
#  'laying': 15,
#  'wears': 15,
#  'very': 15,
#  'flag': 15,
#  'catching': 15,
#  'or': 14,
#  'vest': 14,
#  'six': 14,
#  'ski': 14,
#  'chases': 14,
#  'rail': 14,
#  'clothes': 14,
#  'backpack': 14,
#  'animal': 14,
#  'gets': 14,
#  'points': 14,
#  'male': 14,
#  'waterfall': 14,
#  'wading': 14,
#  'shot': 14,
#  'sliding': 14,
#  'stairs': 14,
#  'bubbles': 13,
#  'setting': 13,
#  'equipment': 13,
#  'feet': 13,
#  'tries': 13,
#  'waiting': 13,
#  'buildings': 13,
#  'restaurant': 13,
#  'steep': 13,
#  'costumes': 13,
#  'right': 13,
#  'bar': 13,
#  'paper': 13,
#  'surrounded': 13,
#  'bucket': 13,
#  'sports': 13,
#  'winter': 13,
#  'bag': 13,
#  'backyard': 13,
#  'between': 13,
#  'stunt': 13,
#  'set': 13,
#  'shirts': 13,
#  'harness': 13,
#  'kick': 13,
#  'bright': 13,
#  'swimsuit': 13,
#  'coming': 12,
#  'kicking': 12,
#  'snowboard': 12,
#  'hiker': 12,
#  'paddling': 12,
#  'dance': 12,
#  'leg': 12,
#  'course': 12,
#  'life': 12,
#  'lone': 12,
#  'deep': 12,
#  'like': 12,
#  'faces': 12,
#  'nose': 12,
#  'sweatshirt': 12,
#  'hurdle': 12,
#  'gloves': 12,
#  'past': 12,
#  'motocross': 12,
#  'metal': 12,
#  'handstand': 12,
#  'guy': 12,
#  'facing': 12,
#  'shoes': 12,
#  'goal': 12,
#  'tricks': 12,
#  'railing': 12,
#  'plastic': 12,
#  'empty': 11,
#  'stage': 11,
#  'bikes': 11,
#  'sticks': 11,
#  'smaller': 11,
#  'canoe': 11,
#  'night': 11,
#  'rowing': 11,
#  'sandy': 11,
#  'bank': 11,
#  'free': 11,
#  'airborne': 11,
#  'they': 11,
#  'cross': 11,
#  'fight': 11,
#  'performs': 11,
#  'diving': 11,
#  'cellphone': 11,
#  'sunny': 11,
#  'swims': 11,
#  'smile': 11,
#  'pictures': 11,
#  'gym': 11,
#  'old': 11,
#  'lot': 11,
#  'skateboarding': 11,
#  'held': 11,
#  'ladder': 11,
#  'tents': 11,
#  'sun': 11,
#  'sprinkler': 11,
#  'silver': 10,
#  'martial': 10,
#  'overlooking': 10,
#  'go': 10,
#  'says': 10,
#  'sprayed': 10,
#  'makes': 10,
#  'fluffy': 10,
#  'statue': 10,
#  'climb': 10,
#  'greyhound': 10,
#  'boxing': 10,
#  'different': 10,
#  'food': 10,
#  'kicks': 10,
#  'staircase': 10,
#  'have': 10,
#  'hit': 10,
#  'hind': 10,
#  'stone': 10,
#  'wood': 10,
#  'follows': 10,
#  'thrown': 10,
#  'full': 10,
#  'driving': 10,
#  'no': 10,
#  'busy': 10,
#  'hugs': 10,
#  'rugby': 10,
#  'paint': 10,
#  'bmx': 10,
#  'dresses': 10,
#  'which': 10,
#  'kissing': 10,
#  'family': 10,
#  'corner': 10,
#  'bed': 10,
#  'coach': 10,
#  'gravel': 9,
#  'cow': 9,
#  'adults': 9,
#  'parking': 9,
#  'eyes': 9,
#  'puts': 9,
#  'outfits': 9,
#  'wheelie': 9,
#  'sniffing': 9,
#  'tongue': 9,
#  'stroller': 9,
#  'mask': 9,
#  'helps': 9,
#  'box': 9,
#  'kiddie': 9,
#  'cement': 9,
#  'gathered': 9,
#  'huge': 9,
#  'drives': 9,
#  'fallen': 9,
#  'swim': 9,
#  'shadow': 9,
#  'leans': 9,
#  'karate': 9,
#  'seat': 9,
#  'surface': 9,
#  'beige': 9,
#  'competition': 9,
#  'foreground': 9,
#  'get': 9,
#  'sleeping': 9,
#  'fire': 9,
#  'concrete': 9,
#  'mud': 9,
#  'carries': 9,
#  'jackets': 9,
#  'wooded': 9,
#  'same': 9,
#  'backwards': 9,
#  'rolling': 9,
#  'low': 9,
#  'vehicle': 9,
#  'drink': 9,
#  'closeup': 8,
#  'splashes': 8,
#  'jungle': 8,
#  'wheel': 8,
#  'blows': 8,
#  'smoking': 8,
#  'newspaper': 8,
#  'lays': 8,
#  'pile': 8,
#  'covering': 8,
#  'mother': 8,
#  'patio': 8,
#  'bull': 8,
#  'blocks': 8,
#  'guys': 8,
#  'drinking': 8,
#  'left': 8,
#  'police': 8,
#  'plants': 8,
#  'clouds': 8,
#  'eats': 8,
#  'bunch': 8,
#  'wetsuit': 8,
#  'ladies': 8,
#  'fenced': 8,
#  'lit': 8,
#  'crowded': 8,
#  'both': 8,
#  'fair': 8,
#  'seated': 8,
#  'splash': 8,
#  'subway': 8,
#  'graffiti': 8,
#  'biting': 8,
#  'cyclist': 8,
#  'tent': 8,
#  'hangs': 8,
#  'teenage': 8,
#  'pack': 8,
#  'hiking': 8,
#  'goggles': 8,
#  'shoulders': 8,
#  'surf': 8,
#  'female': 8,
#  'muzzle': 8,
#  'arts': 8,
#  'skating': 8,
#  'dances': 8,
#  'softball': 8,
#  'dribbles': 8,
#  'talks': 8,
#  'round': 8,
#  'make': 8,
#  'seats': 8,
#  'downhill': 8,
#  'porch': 8,
#  'motorbike': 8,
#  'sooners': 7,
#  'onlookers': 7,
#  'glass': 7,
#  'lies': 7,
#  'court': 7,
#  'phone': 7,
#  'bear': 7,
#  'block': 7,
#  'raft': 7,
#  'structure': 7,
#  'skiers': 7,
#  'public': 7,
#  'pier': 7,
#  'spinning': 7,
#  'scooter': 7,
#  'crossing': 7,
#  'muzzled': 7,
#  'streets': 7,
#  'ring': 7,
#  'break': 7,
#  'throw': 7,
#  'golf': 7,
#  'reaches': 7,
#  'kayak': 7,
#  'lift': 7,
#  'spectators': 7,
#  'slope': 7,
#  'leaning': 7,
#  'base': 7,
#  'couch': 7,
#  'bars': 7,
#  'pulls': 7,
#  'shoulder': 7,
#  'lap': 7,
#  'store': 7,
#  'moving': 7,
#  'boots': 7,
#  'painting': 7,
#  'rolls': 7,
#  'tail': 7,
#  'be': 7,
#  'blanket': 7,
#  'book': 7,
#  'traffic': 7,
#  'attempting': 7,
#  'mirror': 7,
#  'skinned': 7,
#  'gate': 7,
#  'sparklers': 7,
#  'pushes': 7,
#  'flowered': 7,
#  'branch': 7,
#  'rain': 7,
#  'few': 7,
#  'airplane': 7,
#  'motorcyclist': 7,
#  'tattoo': 7,
#  'walkway': 7,
#  'necklace': 7,
#  'chair': 7,
#  'painted': 7,
#  'preparing': 7,
#  'races': 7,
#  'lights': 7,
#  'short': 7,
#  'bends': 7,
#  'lines': 7,
#  'tunnel': 7,
#  'ledge': 6,
#  'barefoot': 6,
#  'wide': 6,
#  'piece': 6,
#  'atop': 6,
#  'whistle': 6,
#  'leading': 6,
#  'reaching': 6,
#  'teal': 6,
#  'hoops': 6,
#  'window': 6,
#  'helmeted': 6,
#  'way': 6,
#  'patch': 6,
#  'skate': 6,
#  'racetrack': 6,
#  'circle': 6,
#  'art': 6,
#  'shoot': 6,
#  'chairs': 6,
#  'scene': 6,
#  'gather': 6,
#  'miami': 6,
#  'bending': 6,
#  'homeless': 6,
#  'bouncing': 6,
#  'younger': 6,
#  'flight': 6,
#  'microphone': 6,
#  'headband': 6,
#  'part': 6,
#  'pirate': 6,
#  'hose': 6,
#  'dust': 6,
#  'fast': 6,
#  'using': 6,
#  'party': 6,
#  'indoors': 6,
#  'having': 6,
#  'pavement': 6,
#  'before': 6,
#  'dives': 6,
#  'audience': 6,
#  'hillside': 6,
#  'teenagers': 6,
#  'puddle': 6,
#  'plain': 6,
#  'balancing': 6,
#  'falling': 6,
#  'pipe': 6,
#  'garden': 6,
#  'indoor': 6,
#  'lined': 6,
#  'landscape': 6,
#  'living': 6,
#  'racket': 6,
#  'ears': 6,
#  'mouths': 6,
#  'station': 6,
#  'bags': 6,
#  'bikini': 6,
#  'beautiful': 6,
#  'practicing': 6,
#  'shaking': 6,
#  'below': 6,
#  'hoodie': 6,
#  'examine': 6,
#  'pushing': 6,
#  'finger': 6,
#  'collie': 6,
#  'coffee': 6,
#  'fingers': 6,
#  'shakes': 6,
#  'teams': 6,
#  'jet': 6,
#  'log': 6,
#  'boxer': 6,
#  'poles': 6,
#  'fancy': 5,
#  'attire': 5,
#  'moves': 5,
#  'school': 5,
#  'dry': 5,
#  'appears': 5,
#  'hits': 5,
#  'map': 5,
#  'writing': 5,
#  'indian': 5,
#  'stools': 5,
#  'quickly': 5,
#  'throws': 5,
#  'foot': 5,
#  '5': 5,
#  'punching': 5,
#  'eat': 5,
#  'bay': 5,
#  'seen': 5,
#  'hold': 5,
#  'students': 5,
#  'cowboy': 5,
#  'pajamas': 5,
#  'corn': 5,
#  'gear': 5,
#  'filled': 5,
#  'cake': 5,
#  'but': 5,
#  'milkshake': 5,
#  'counter': 5,
#  'cardboard': 5,
#  'atv': 5,
#  'staring': 5,
#  'dirty': 5,
#  'merry': 5,
#  'fall': 5,
#  'where': 5,
#  'elderly': 5,
#  'gold': 5,
#  'mohawk': 5,
#  'work': 5,
#  'skates': 5,
#  'wear': 5,
#  'enjoying': 5,
#  'reads': 5,
#  'fly': 5,
#  'talk': 5,
#  'suits': 5,
#  'close': 5,
#  'shoreline': 5,
#  'string': 5,
#  'christmas': 5,
#  'asleep': 5,
#  'single': 5,
#  'ridden': 5,
#  'bottom': 5,
#  'pumpkins': 5,
#  'paintball': 5,
#  'inflatable': 5,
#  'sticking': 5,
#  'spoon': 5,
#  'terrain': 5,
#  'skateboards': 5,
#  'outstretched': 5,
#  'casts': 5,
#  'action': 5,
#  'towel': 5,
#  'pet': 5,
#  'direction': 5,
#  'sport': 5,
#  'flower': 5,
#  'clear': 5,
#  'bowling': 5,
#  'tourists': 5,
#  'goes': 5,
#  'formation': 5,
#  'larger': 5,
#  'puffy': 5,
#  'neon': 5,
#  'door': 5,
#  'underneath': 5,
#  'wrestle': 5,
#  'half': 5,
#  'stadium': 5,
#  'paws': 5,
#  'event': 5,
#  'african': 5,
#  'putting': 5,
#  'snake': 5,
#  'crown': 5,
#  'blurry': 5,
#  'twin': 5,
#  'aerial': 5,
#  'lands': 5,
#  'stop': 5,
#  'neck': 5,
#  'chase': 5,
#  'parachute': 5,
#  'muddy': 5,
#  'monkey': 5,
#  'hats': 5,
#  'horses': 5,
#  'mound': 5,
#  'raised': 5,
#  'pit': 5,
#  'creek': 5,
#  'reach': 5,
#  'cloudy': 5,
#  'opposing': 5,
#  'war': 5,
#  'parade': 5,
#  'kiss': 5,
#  'made': 5,
#  'kangaroo': 5,
#  'chalk': 5,
#  'throwing': 5,
#  'drinks': 5,
#  'float': 5,
#  'resting': 5,
#  'without': 5,
#  'speaking': 5,
#  'tug': 5,
#  'bites': 5,
#  'bushes': 5,
#  'puppies': 5,
#  'take': 5,
#  'bandanna': 5,
#  'forward': 5,
#  'waits': 5,
#  'fish': 5,
#  'show': 5,
#  'wagon': 5,
#  'hitting': 5,
#  'deer': 5,
#  'dribbling': 5,
#  'photograph': 5,
#  'chip': 5,
#  'pass': 5,
#  'these': 5,
#  'alley': 5,
#  'cricket': 5,
#  'shaggy': 5,
#  'spots': 5,
#  'beard': 5,
#  'binoculars': 5,
#  'courtyard': 5,
#  'sleeved': 5,
#  'row': 5,
#  'sweaters': 5,
#  'computer': 5,
#  'band': 5,
#  'fireworks': 5,
#  'played': 4,
#  'among': 4,
#  'leather': 4,
#  'great': 4,
#  'club': 4,
#  'hound': 4,
#  'gondola': 4,
#  'put': 4,
#  'sink': 4,
#  'grabs': 4,
#  'poodle': 4,
#  'practices': 4,
#  'paddles': 4,
#  'unfinished': 4,
#  'drums': 4,
#  'scales': 4,
#  'enjoys': 4,
#  'music': 4,
#  'mexican': 4,
#  'snowsuit': 4,
#  'einstein': 4,
#  'sheep': 4,
#  'time': 4,
#  'himself': 4,
#  'grinding': 4,
#  'foggy': 4,
#  'backpacks': 4,
#  'lane': 4,
#  'benches': 4,
#  'dropping': 4,
#  'seven': 4,
#  'teenager': 4,
#  'attached': 4,
#  'stairway': 4,
#  'crawling': 4,
#  'referee': 4,
#  'expressions': 4,
#  'sword': 4,
#  'noodle': 4,
#  'babies': 4,
#  'bend': 4,
#  'view': 4,
#  'meadow': 4,
#  'though': 4,
#  'begins': 4,
#  'print': 4,
#  'kneeling': 4,
#  'spray': 4,
#  'raises': 4,
#  'smoke': 4,
#  'backs': 4,
#  'firetruck': 4,
#  'attempts': 4,
#  'pointed': 4,
#  'denim': 4,
#  'midst': 4,
#  'pharmacy': 4,
#  'performer': 4,
#  'help': 4,
#  'topless': 4,
#  'perform': 4,
#  'runners': 4,
#  'surfs': 4,
#  'competing': 4,
#  'cigarette': 4,
#  'handlebars': 4,
#  'rafting': 4,
#  'escalator': 4,
#  'starting': 4,
#  'human': 4,
#  'leaving': 4,
#  ...}

# %%
# import nltk
# postags = nltk.pos_tag(worddf["words"])

# %%
from helper import return_postag_keys

# %%
textcp = pd.read_csv(path, sep="\t",header=None)
textcp.columns = ["images","captions"]
textcp["original"] = textcp["images"]
textcp.images = [words[:-6] for words in textcp.images if words==words]
textcp = textcp[textcp.images.isin(testset)]
textcp = textcp.drop(columns = "images")
textcp
textcp.to_csv("/Users/sebastiaanscholten/Documents/speech2image-master/vgsexperiments/experiments/Results_isolated_word_recognition/documents/textcp.csv",index=False)

# %%
def match_word_wavfile():
    inputword = input("Enter word here: ")
    wavfiles = []
    for idx, captions in enumerate(textcp.captions):
        if inputword in tokenizer.tokenize(captions):
            wavfiles.append(textcp.original.iloc[idx])
    wavfilenames = []
    for word in wavfiles:
        word = word.replace("#","_")
        word = word.replace(".jpg","")
        wavfilenames.append(word)
    return wavfilenames,inputword,wavfiles

# %%
wavfilenames,inputword,wavfiles = match_word_wavfile()
# Out:
# Enter word here:

# %%
len(wavfilenames)
# Out:
# 0

# %%
# def seperate_files_from_list(inputwords):
#     #loop through the words
#     for inputword in inputwords:
#         wavfiles = []
#         #find captions that contain these words
#         for idx, captions in enumerate(textcp.captions):
#             if inputword in tokenizer.tokenize(captions):
#                 wavfiles.append(textcp.original.iloc[idx])
#         wavfilenames = []
#         #preprocess them for file copying
#         for word in wavfiles:
#             word = word.replace("#","_")
#             word = word.replace(".jpg","")
#             wavfilenames.append(word)
#         count = 0
#         source = "/Volumes/Schnellheit/ThesisData/flickrwavsandimagestextandjson/flickr_audio/wavs/"
#         dest = "/Volumes/Schnellheit/ThesisData/flickrwavsandimagestextandjson/flickr_audio/" + inputword + "/"
#         #move the files
#         if not os.path.exists(dest):
#             os.mkdir(dest)
#         for word in wavfilenames:
#             count = count + 1
#             word = word + ".wav"
#             sourceword = source + word
#             worddest = dest + word
#             shutil.copy(sourceword,worddest)
#             if count == 50:
#                 count = 0
#                 break
# listtest = ["dog","man","boy","girl","woman","people"
#             ,"dogs","shirt","child","ball","person"
#             ,"children","men","girls","bike","rock","camera"
#             ,"boys","hat","player","jacket","basketball","swing"
#             ,"car", "wall", "hair","football","sunglasses","head"
#             ,"shorts","dress","table"]

# # seperate_files_from_list(listtest)

# %%
from collections import defaultdict
def print_file_list(inputwords):
    #loop through the words
    word_appended_finallist = []
    finallist = []
    finallistdict = defaultdict(list)
    for inputword in inputwords:
        wavfiles = []
        #find captions that contain these words
        for idx, captions in enumerate(textcp.captions):
            if inputword in tokenizer.tokenize(captions):
                wavfiles.append(textcp.original.iloc[idx])
        wavfilenames = []
        #preprocess them for file copying
        for word in wavfiles:
            word = word.replace("#","_")
            word = word.replace(".jpg","")
            wordwithinputword = inputword + "_" + word
            wavfilenames.append(word)
        count = 0
        #move the files
        for word in wavfilenames:
            count = count + 1
            word_appended_finallist.append(wordwithinputword)
            finallist.append(word)
            file = word.split('_', -1)[0:2]
            testword = "_".join(file)
            wordjpg = testword + ".jpg"
            finallistdict[wordjpg].append(inputword)
            if count == 50:
                count = 0
                break         
    return wavfiles,wavfilenames,word_appended_finallist,finallist,finallistdict

# %%
listtest2 = ["dog","man","boy","girl","woman","people"
            ,"dogs","shirt","child","ball","person"
            ,"children","men","girls","bike","rock","camera"
            ,"boys","hat","player","jacket","basketball","swing"
            ,"car", "wall", "hair","football","sunglasses","head"
            ,"shorts","dress","table","water","grass","bench","snow"
            ,"air","field","street","mouth","dirt","mountain","pool"
            ,"ocean","sand","building","soccer","park","face"]

# %%
len(listtest2)
# Out:
# 49

# %%
wavfiles, wavfilenames,word_appended_finallist,finallist,finallistdict = print_file_list(listtest2)

# %%
word_appended_finallist = pd.DataFrame(word_appended_finallist)
word_appended_finallist.to_csv("word_appended_finallist.txt",index=False,header=False)

finallist = pd.DataFrame(finallist)
finallist.to_csv("finallist.txt",index=False,header=False)

# %%
finallistdict
# Out:
# defaultdict(list,
#             {'1084040636_97d9633581.jpg': ['dog',
#               'dog',
#               'dog',
#               'dog',
#               'dog',
#               'head',
#               'head',
#               'head',
#               'head'],
#              '1107246521_d16a476380.jpg': ['dog',
#               'dog',
#               'dog',
#               'dog',
#               'dog',
#               'ball'],
#              '1119015538_e8e796281e.jpg': ['dog',
#               'dog',
#               'dog',
#               'dog',
#               'dogs',
#               'grass',
#               'grass',
#               'grass',
#               'field'],
#              '1131800850_89c7ffd477.jpg': ['dog',
#               'dog',
#               'dog',
#               'dog',
#               'dog',
#               'water',
#               'water',
#               'water'],
#              '1267711451_e2a754b4f8.jpg': ['dog',
#               'dog',
#               'dog',
#               'dog',
#               'dog',
#               'grass',
#               'mouth',
#               'mouth',
#               'mouth',
#               'mouth'],
#              '1287073593_f3d2a62455.jpg': ['dog',
#               'man',
#               'dogs',
#               'dogs',
#               'dogs',
#               'person',
#               'person',
#               'snow',
#               'snow'],
#              '1392272228_cf104086e6.jpg': ['dog',
#               'dog',
#               'dog',
#               'dog',
#               'dog',
#               'water',
#               'water',
#               'water',
#               'water',
#               'mouth',
#               'mouth',
#               'ocean'],
#              '1394368714_3bc7c19969.jpg': ['dog',
#               'dog',
#               'dog',
#               'man',
#               'man',
#               'man',
#               'person'],
#              '1425069308_488e5fcf9d.jpg': ['dog',
#               'dog',
#               'dog',
#               'dog',
#               'dogs',
#               'ball',
#               'ball',
#               'ball',
#               'ball',
#               'ball',
#               'air',
#               'air',
#               'mouth',
#               'mouth'],
#              '1490213660_9ea45550cf.jpg': ['dog', 'dog', 'dog', 'dog'],
#              '1517721825_10176d0683.jpg': ['dog',
#               'dogs',
#               'dogs',
#               'dogs',
#               'dogs',
#               'water',
#               'water',
#               'water',
#               'ocean'],
#              '1523984678_edd68464da.jpg': ['dog',
#               'dog',
#               'dog',
#               'dog',
#               'dog',
#               'ball',
#               'ball',
#               'ball',
#               'ball',
#               'ball',
#               'grass',
#               'grass',
#               'mouth',
#               'mouth',
#               'mouth'],
#              '1554713437_61b64527dd.jpg': ['dog', 'dog', 'dog'],
#              '1082379191_ec1e53f996.jpg': ['man',
#               'man',
#               'man',
#               'man',
#               'man',
#               'woman',
#               'woman',
#               'woman',
#               'woman',
#               'shirt'],
#              '1167669558_87a8a467d6.jpg': ['man',
#               'man',
#               'man',
#               'man',
#               'man',
#               'shirt',
#               'shirt',
#               'shirt',
#               'camera',
#               'face',
#               'face'],
#              '1262583859_653f1469a9.jpg': ['man',
#               'man',
#               'man',
#               'man',
#               'shirt',
#               'shirt',
#               'shirt',
#               'bike',
#               'bike',
#               'sunglasses'],
#              '127488876_f2d2a89588.jpg': ['man',
#               'shirt',
#               'men',
#               'men',
#               'shorts'],
#              '132489044_3be606baf7.jpg': ['man', 'man', 'man', 'man', 'man'],
#              '1343426964_cde3fb54e8.jpg': ['man',
#               'boy',
#               'girl',
#               'shirt',
#               'child',
#               'water'],
#              '136552115_6dc3e7231c.jpg': ['man',
#               'man',
#               'person',
#               'bike',
#               'bike',
#               'bike',
#               'bike',
#               'rock',
#               'rock',
#               'rock',
#               'rock',
#               'dirt',
#               'mountain',
#               'mountain'],
#              '136886677_6026c622eb.jpg': ['man', 'man', 'men', 'men'],
#              '1404832008_68e432665b.jpg': ['man',
#               'man',
#               'man',
#               'man',
#               'man',
#               'water',
#               'water',
#               'water',
#               'water',
#               'water'],
#              '1432179046_8e3d75cf81.jpg': ['man',
#               'man',
#               'man',
#               'man',
#               'car',
#               'wall',
#               'wall',
#               'building'],
#              '1433142189_cda8652603.jpg': ['man', 'man', 'grass'],
#              '143688283_a96ded20f1.jpg': ['man',
#               'man',
#               'man',
#               'man',
#               'shirt',
#               'shirt',
#               'rock',
#               'rock',
#               'rock',
#               'wall',
#               'wall',
#               'mountain'],
#              '1461667284_041c8a2475.jpg': ['man',
#               'man',
#               'man',
#               'woman',
#               'woman',
#               'people',
#               'people',
#               'hat'],
#              '1499581619_a5f65a882c.jpg': ['man',
#               'man',
#               'girl',
#               'woman',
#               'people',
#               'jacket',
#               'sunglasses'],
#              '150387174_24825cf871.jpg': ['man',
#               'bike',
#               'bike',
#               'bike',
#               'dirt',
#               'dirt',
#               'dirt'],
#              '106490881_5a2dd9b7bd.jpg': ['boy',
#               'boy',
#               'boy',
#               'boy',
#               'camera',
#               'shorts',
#               'ocean'],
#              '1096395242_fc69f0ae5a.jpg': ['boy',
#               'boy',
#               'boy',
#               'child',
#               'camera',
#               'camera',
#               'shorts'],
#              '1131932671_c8d17751b3.jpg': ['boy',
#               'boy',
#               'boy',
#               'boy',
#               'child',
#               'shorts'],
#              '114051287_dd85625a04.jpg': ['boy',
#               'boy',
#               'boy',
#               'boy',
#               'shirt',
#               'child',
#               'car',
#               'car',
#               'car',
#               'soccer',
#               'soccer',
#               'soccer',
#               'soccer'],
#              '1224851143_33bcdd299c.jpg': ['boy',
#               'boy',
#               'boy',
#               'child',
#               'child',
#               'mouth',
#               'mouth'],
#              '1287475186_2dee85f1a5.jpg': ['boy',
#               'boy',
#               'boy',
#               'boy',
#               'boy',
#               'water',
#               'water',
#               'water',
#               'water',
#               'water',
#               'pool'],
#              '1298295313_db1f4c6522.jpg': ['boy',
#               'boy',
#               'boy',
#               'boy',
#               'boy',
#               'jacket',
#               'jacket',
#               'shorts',
#               'water'],
#              '1317292658_ba29330a0b.jpg': ['boy',
#               'boy',
#               'boy',
#               'boy',
#               'boy',
#               'water',
#               'water',
#               'water'],
#              '1322323208_c7ecb742c6.jpg': ['boy',
#               'boy',
#               'girl',
#               'children',
#               'children',
#               'children',
#               'girls',
#               'sand'],
#              '136644343_0e2b423829.jpg': ['boy',
#               'boy',
#               'boy',
#               'boy',
#               'boy',
#               'camera',
#               'swing',
#               'swing',
#               'swing',
#               'swing',
#               'swing'],
#              '1386964743_9e80d96b05.jpg': ['boy',
#               'child',
#               'child',
#               'child',
#               'camera',
#               'car',
#               'hair',
#               'field',
#               'field',
#               'dirt',
#               'dirt'],
#              '1402640441_81978e32a9.jpg': ['boy',
#               'boy',
#               'boy',
#               'boy',
#               'ball',
#               'ball',
#               'ball',
#               'ball',
#               'ball',
#               'shorts',
#               'sand',
#               'soccer',
#               'soccer',
#               'soccer',
#               'soccer',
#               'face'],
#              '1427391496_ea512cbe7f.jpg': ['boy',
#               'boy',
#               'shirt',
#               'child',
#               'child',
#               'camera',
#               'table',
#               'water',
#               'water'],
#              '1456393634_74022d9056.jpg': ['boy',
#               'boy',
#               'child',
#               'child',
#               'sand'],
#              '1174525839_7c1e6cfa86.jpg': ['girl',
#               'girl',
#               'girl',
#               'girl',
#               'girls',
#               'air',
#               'air',
#               'air',
#               'ocean',
#               'ocean'],
#              '1237985362_dbafc59280.jpg': ['girl',
#               'girl',
#               'girl',
#               'girl',
#               'woman',
#               'woman',
#               'woman',
#               'woman',
#               'shirt',
#               'dress'],
#              '127490019_7c5c08cb11.jpg': ['girl',
#               'woman',
#               'woman',
#               'woman',
#               'woman',
#               'shirt',
#               'shirt',
#               'hat',
#               'swing',
#               'swing',
#               'swing',
#               'shorts',
#               'shorts'],
#              '1282392036_5a0328eb86.jpg': ['girl',
#               'woman',
#               'people',
#               'child',
#               'child'],
#              '1348304997_afe60a61df.jpg': ['girl',
#               'girl',
#               'girl',
#               'girl',
#               'child',
#               'hair'],
#              '1352410176_af6b139734.jpg': ['girl',
#               'girl',
#               'girl',
#               'girl',
#               'ocean',
#               'sand',
#               'sand'],
#              '1356796100_b265479721.jpg': ['girl',
#               'girl',
#               'girl',
#               'girl',
#               'girl',
#               'dress',
#               'face'],
#              '1387785218_cee67735f5.jpg': ['girl',
#               'child',
#               'child',
#               'child',
#               'street'],
#              '1389264266_8170bc1c54.jpg': ['girl',
#               'shirt',
#               'girls',
#               'girls',
#               'girls',
#               'girls',
#               'camera',
#               'hair',
#               'street',
#               'face'],
#              '1408958345_68eea9a4e4.jpg': ['girl',
#               'girl',
#               'girl',
#               'girl',
#               'girl',
#               'sand'],
#              '1415591512_a84644750c.jpg': ['girl',
#               'girl',
#               'girl',
#               'girl',
#               'girl',
#               'car',
#               'car',
#               'car',
#               'car',
#               'hair',
#               'grass',
#               'grass'],
#              '1547883892_e29b3db42e.jpg': ['girl',
#               'woman',
#               'woman',
#               'woman',
#               'woman',
#               'hat',
#               'hat'],
#              '1561658940_a947f2446a.jpg': ['girl',
#               'girl',
#               'girl',
#               'girl',
#               'swing',
#               'swing',
#               'swing',
#               'swing',
#               'swing'],
#              '1682079482_9a72fa57fa.jpg': ['girl',
#               'girl',
#               'girl',
#               'girl',
#               'shirt',
#               'swing',
#               'swing',
#               'swing',
#               'swing'],
#              '170100272_d820db2199.jpg': ['girl',
#               'girl',
#               'girl',
#               'child',
#               'child',
#               'park',
#               'park'],
#              '1056338697_4f7d7ce270.jpg': ['woman',
#               'woman',
#               'woman',
#               'woman',
#               'woman',
#               'shirt',
#               'hair',
#               'dress',
#               'street',
#               'street'],
#              '1332722096_1e3de8ae70.jpg': ['woman',
#               'woman',
#               'girls',
#               'girls',
#               'street',
#               'street'],
#              '1982852140_56425fa7a2.jpg': ['woman',
#               'people',
#               'people',
#               'people',
#               'child',
#               'ocean',
#               'sand'],
#              '2049051050_20359a434a.jpg': ['woman',
#               'woman',
#               'woman',
#               'rock',
#               'rock',
#               'hat',
#               'hat',
#               'hat',
#               'hat',
#               'jacket',
#               'sand',
#               'sand'],
#              '2073964624_52da3a0fc4.jpg': ['woman',
#               'woman',
#               'woman',
#               'woman',
#               'woman',
#               'bike',
#               'bike',
#               'bike',
#               'hat',
#               'hat',
#               'hat',
#               'hat',
#               'park'],
#              '2083434441_a93bc6306b.jpg': ['woman',
#               'woman',
#               'woman',
#               'woman',
#               'woman',
#               'car',
#               'hair',
#               'street',
#               'street',
#               'street'],
#              '2084217208_7bd9bc85e5.jpg': ['woman',
#               'woman',
#               'woman',
#               'woman',
#               'person',
#               'bike',
#               'bike',
#               'bike',
#               'bike',
#               'jacket',
#               'jacket',
#               'park'],
#              '2086513494_dbbcb583e7.jpg': ['woman',
#               'woman',
#               'people',
#               'camera',
#               'jacket'],
#              '2182488373_df73c7cc09.jpg': ['woman',
#               'hat',
#               'sunglasses',
#               'street',
#               'street',
#               'street'],
#              '219301555_17883a51bd.jpg': ['woman',
#               'woman',
#               'shirt',
#               'shorts',
#               'pool'],
#              '115684808_cb01227802.jpg': ['people',
#               'people',
#               'people',
#               'men',
#               'men',
#               'snow',
#               'snow'],
#              '1174629344_a2e1a2bdbf.jpg': ['people',
#               'people',
#               'people',
#               'street'],
#              '1258913059_07c613f7ff.jpg': ['people',
#               'people',
#               'people',
#               'people',
#               'people',
#               'table',
#               'table',
#               'table',
#               'bench',
#               'building',
#               'building'],
#              '1329832826_432538d331.jpg': ['people',
#               'people',
#               'street',
#               'street',
#               'street',
#               'street'],
#              '138718600_f430ebca17.jpg': ['people',
#               'people',
#               'girls',
#               'water',
#               'water',
#               'grass',
#               'grass',
#               'grass'],
#              '1472230829_803818a383.jpg': ['people',
#               'people',
#               'people',
#               'water',
#               'water'],
#              '1472882567_33dc14c8b6.jpg': ['people',
#               'snow',
#               'snow',
#               'snow',
#               'mountain',
#               'mountain'],
#              '1536774449_e16b1b6382.jpg': ['people',
#               'people',
#               'people',
#               'people',
#               'building'],
#              '160792599_6a7ec52516.jpg': ['people',
#               'people',
#               'people',
#               'men',
#               'men',
#               'water',
#               'water',
#               'ocean',
#               'ocean',
#               'ocean',
#               'sand'],
#              '1773928579_5664a810dc.jpg': ['people'],
#              '180094434_b0f244832d.jpg': ['people',
#               'boys',
#               'boys',
#               'building',
#               'building'],
#              '180506881_de0f59770f.jpg': ['people',
#               'people',
#               'people',
#               'camera'],
#              '1962729184_6996e128e7.jpg': ['people',
#               'children',
#               'children',
#               'water'],
#              '2064790732_219e52e19c.jpg': ['people',
#               'people',
#               'people',
#               'shirt',
#               'shirt',
#               'street',
#               'street'],
#              '2096771662_984441d20d.jpg': ['people', 'men', 'men'],
#              '215214751_e913b6ff09.jpg': ['people', 'people', 'men', 'men'],
#              '2176980976_7054c99621.jpg': ['people',
#               'people',
#               'people',
#               'people',
#               'mountain',
#               'mountain',
#               'mountain',
#               'mountain'],
#              '1897025969_0c41688fa6.jpg': ['dogs', 'dogs', 'sand', 'sand'],
#              '2120411340_104eb610b1.jpg': ['dogs', 'head', 'mountain'],
#              '2148916767_644ea6a7fa.jpg': ['dogs',
#               'head',
#               'snow',
#               'snow',
#               'snow',
#               'snow'],
#              '2216695423_1362cb25f3.jpg': ['dogs',
#               'dogs',
#               'dogs',
#               'dogs',
#               'grass'],
#              '2239938351_43c73c887c.jpg': ['dogs',
#               'dogs',
#               'dogs',
#               'ball',
#               'ball',
#               'ball',
#               'ball',
#               'ball',
#               'grass',
#               'grass',
#               'mouth'],
#              '2308271254_27fb466eb4.jpg': ['dogs', 'dogs', 'dogs'],
#              '2310126952_7dc86d88f6.jpg': ['dogs', 'dogs', 'snow', 'snow'],
#              '2340206885_58754a799a.jpg': ['dogs',
#               'dogs',
#               'dogs',
#               'dogs',
#               'dogs',
#               'snow',
#               'snow',
#               'snow',
#               'snow',
#               'field',
#               'face'],
#              '2358561039_e215a8d6cd.jpg': ['dogs',
#               'dogs',
#               'dogs',
#               'dogs',
#               'bike',
#               'snow',
#               'snow',
#               'snow'],
#              '2398605966_1d0c9e6a20.jpg': ['dogs', 'dogs', 'dogs', 'dogs'],
#              '2410320522_d967f0b75c.jpg': ['dogs',
#               'dogs',
#               'dogs',
#               'grass',
#               'grass',
#               'field'],
#              '2414397449_2ac3b78e0d.jpg': ['dogs',
#               'dogs',
#               'head',
#               'grass',
#               'grass',
#               'grass',
#               'field',
#               'field'],
#              '2419221084_01a14176b4.jpg': ['dogs', 'dogs', 'dogs', 'dogs'],
#              '244571201_0339d8e8d1.jpg': ['dogs',
#               'dogs',
#               'dogs',
#               'pool',
#               'pool',
#               'pool',
#               'pool',
#               'pool',
#               'park',
#               'park'],
#              '1509786421_f03158adfc.jpg': ['shirt', 'child'],
#              '1765164972_92dac06fa9.jpg': ['shirt',
#               'shirt',
#               'shirt',
#               'person',
#               'person',
#               'person',
#               'person',
#               'hair'],
#              '189721896_1ffe76d89e.jpg': ['shirt',
#               'rock',
#               'rock',
#               'rock',
#               'rock',
#               'wall',
#               'mountain',
#               'face'],
#              '191003285_edd8d0cf58.jpg': ['shirt', 'shirt', 'dress', 'street'],
#              '2021613437_d99731f986.jpg': ['shirt',
#               'shirt',
#               'child',
#               'basketball',
#               'basketball',
#               'basketball',
#               'basketball',
#               'basketball'],
#              '2120383553_5825333a3f.jpg': ['shirt'],
#              '2196107384_361d73a170.jpg': ['shirt',
#               'person',
#               'hat',
#               'street',
#               'building',
#               'building',
#               'building'],
#              '2224450291_4c133fabe8.jpg': ['shirt',
#               'person',
#               'camera',
#               'camera',
#               'camera',
#               'camera',
#               'face'],
#              '2306674172_dc07c7f847.jpg': ['shirt', 'air', 'building'],
#              '2307118114_c258e3a47e.jpg': ['shirt',
#               'shirt',
#               'shirt',
#               'shirt',
#               'hat',
#               'hat'],
#              '2309860995_c2e2a0feeb.jpg': ['shirt',
#               'shirt',
#               'camera',
#               'jacket',
#               'hair',
#               'sunglasses',
#               'sunglasses',
#               'sunglasses'],
#              '2343525685_3eba3b6686.jpg': ['shirt',
#               'rock',
#               'rock',
#               'rock',
#               'rock',
#               'wall',
#               'wall',
#               'wall',
#               'wall',
#               'wall'],
#              '2384353160_f395e9a54b.jpg': ['shirt',
#               'camera',
#               'camera',
#               'hat',
#               'hat',
#               'hat',
#               'sunglasses'],
#              '241031254_0c6f30e3d1.jpg': ['shirt',
#               'shirt',
#               'shirt',
#               'shorts',
#               'shorts',
#               'shorts'],
#              '241347760_d44c8d3a01.jpg': ['shirt',
#               'player',
#               'player',
#               'football',
#               'football',
#               'football',
#               'football'],
#              '2415803492_56a673dc25.jpg': ['shirt'],
#              '2436081047_bca044c1d3.jpg': ['shirt',
#               'shirt',
#               'swing',
#               'swing',
#               'swing',
#               'swing',
#               'swing'],
#              '1490670858_e122df2560.jpg': ['child'],
#              '1714316707_8bbaa2a2ba.jpg': ['child',
#               'person',
#               'jacket',
#               'jacket',
#               'snow',
#               'snow',
#               'snow',
#               'snow',
#               'snow'],
#              '1998457059_c9ac9a1e1a.jpg': ['child', 'water', 'ocean', 'ocean'],
#              '2041867793_552819a40b.jpg': ['child',
#               'child',
#               'child',
#               'table',
#               'table',
#               'face'],
#              '2061144717_5b3a1864f0.jpg': ['child'],
#              '2128119486_4407061c40.jpg': ['child', 'mouth', 'mouth', 'face'],
#              '2140182410_8e2a06fbda.jpg': ['child',
#               'person',
#               'person',
#               'snow',
#               'snow',
#               'snow',
#               'snow',
#               'snow'],
#              '2183227136_8bb657846b.jpg': ['child',
#               'child',
#               'person',
#               'ocean',
#               'sand',
#               'sand'],
#              '2197275664_fabcf3424b.jpg': ['child'],
#              '2208067635_39a03834ca.jpg': ['child',
#               'rock',
#               'rock',
#               'rock',
#               'rock',
#               'rock'],
#              '2208310655_a3d83080c5.jpg': ['child',
#               'children',
#               'boys',
#               'face'],
#              '2215136723_960edfea49.jpg': ['child',
#               'jacket',
#               'snow',
#               'snow',
#               'snow'],
#              '2274992140_bb9e868bb8.jpg': ['child',
#               'child',
#               'children',
#               'children',
#               'children'],
#              '2333288869_8c01e4c859.jpg': ['child',
#               'child',
#               'ocean',
#               'ocean',
#               'ocean'],
#              '2354540393_a149722680.jpg': ['child', 'children'],
#              '2358554995_54ed3baa83.jpg': ['child', 'child', 'child'],
#              '2378149488_648e5deeac.jpg': ['child', 'jacket'],
#              '2393264648_a280744f97.jpg': ['child', 'child', 'camera'],
#              '154871781_ae77696b77.jpg': ['ball',
#               'ball',
#               'ball',
#               'boys',
#               'boys',
#               'boys',
#               'grass',
#               'field',
#               'soccer',
#               'soccer',
#               'soccer',
#               'park'],
#              '1764955991_5e53a28c87.jpg': ['ball', 'ball', 'ball', 'mouth'],
#              '1786425974_c7c5ad6aa1.jpg': ['ball', 'person'],
#              '197504190_fd1fc3d4b7.jpg': ['ball',
#               'ball',
#               'ball',
#               'ball',
#               'children',
#               'children',
#               'children',
#               'boys',
#               'boys',
#               'grass',
#               'grass',
#               'grass',
#               'field',
#               'soccer',
#               'soccer',
#               'soccer',
#               'soccer',
#               'park'],
#              '2160266952_a2ab39191b.jpg': ['ball',
#               'children',
#               'children',
#               'children'],
#              '2370481277_a3085614c9.jpg': ['ball',
#               'ball',
#               'ball',
#               'children',
#               'boys',
#               'boys',
#               'boys',
#               'field',
#               'field',
#               'soccer',
#               'soccer',
#               'soccer',
#               'soccer',
#               'soccer'],
#              '241346508_0b3907a95b.jpg': ['ball',
#               'football',
#               'football',
#               'football',
#               'football',
#               'football',
#               'field'],
#              '2443380641_7b38d18f5b.jpg': ['ball', 'ball'],
#              '2475162978_2c51048dca.jpg': ['ball', 'ball', 'ball'],
#              '2502905671_c6039804ab.jpg': ['ball', 'ocean'],
#              '2526041608_a9775ab8d7.jpg': ['ball',
#               'boys',
#               'player',
#               'player',
#               'football',
#               'football',
#               'football',
#               'football',
#               'football'],
#              '2587818583_4aa8e7b174.jpg': ['ball',
#               'ball',
#               'ball',
#               'ball',
#               'ball',
#               'children',
#               'children',
#               'men'],
#              '2648165716_02e2e74fd6.jpg': ['ball', 'swing', 'air'],
#              '1311388430_4ab0cd1a1f.jpg': ['person',
#               'person',
#               'person',
#               'air'],
#              '1417031097_ab656bc4bd.jpg': ['person', 'park', 'park'],
#              '1584315962_5b0b45d02d.jpg': ['person', 'snow'],
#              '197107117_4b438b1872.jpg': ['person',
#               'person',
#               'rock',
#               'rock',
#               'rock',
#               'air',
#               'mountain'],
#              '2061354254_faa5bd294b.jpg': ['person', 'swing'],
#              '2073105823_6dacade004.jpg': ['person', 'person', 'snow'],
#              '2124040721_bffc0a091a.jpg': ['person',
#               'person',
#               'hat',
#               'hat',
#               'hat',
#               'hat',
#               'hat',
#               'jacket',
#               'jacket',
#               'hair',
#               'hair',
#               'hair',
#               'snow'],
#              '2192131110_8a40e7c028.jpg': ['person',
#               'swing',
#               'swing',
#               'swing',
#               'swing'],
#              '2194494220_bb2178832c.jpg': ['person',
#               'person',
#               'snow',
#               'mountain'],
#              '223299142_521aedf9e7.jpg': ['person',
#               'grass',
#               'mountain',
#               'mountain',
#               'mountain'],
#              '2256133102_e2c8314ecb.jpg': ['person', 'ocean'],
#              '2265096094_8cc34d669c.jpg': ['person', 'car', 'dirt'],
#              '2289068031_fe26990183.jpg': ['person',
#               'men',
#               'camera',
#               'air',
#               'air',
#               'dirt'],
#              '2311690895_0d6efe11c8.jpg': ['person',
#               'person',
#               'person',
#               'mouth',
#               'mouth'],
#              '2317714088_bcd081f926.jpg': ['person',
#               'person',
#               'snow',
#               'snow',
#               'snow'],
#              '2396025708_e4a72e2558.jpg': ['person', 'ocean', 'ocean'],
#              '2473689180_e9d8fd656a.jpg': ['person', 'air'],
#              '2473738924_eca928d12f.jpg': ['person',
#               'girls',
#               'girls',
#               'girls',
#               'girls',
#               'girls'],
#              '2479162876_a5ce3306af.jpg': ['person', 'dirt', 'mountain'],
#              '260828892_7925d27865.jpg': ['person',
#               'person',
#               'dress',
#               'ocean',
#               'sand',
#               'sand',
#               'sand'],
#              '2666205903_8d287669e1.jpg': ['person',
#               'person',
#               'girls',
#               'hair'],
#              '2677656448_6b7e7702af.jpg': ['person',
#               'pool',
#               'pool',
#               'pool',
#               'pool',
#               'pool'],
#              '270816949_ffad112278.jpg': ['person',
#               'field',
#               'mountain',
#               'mountain'],
#              '1220401002_3f44b1f3f7.jpg': ['children',
#               'girls',
#               'girls',
#               'girls',
#               'girls',
#               'grass',
#               'grass',
#               'face'],
#              '1248940539_46d33ed487.jpg': ['children',
#               'children',
#               'girls',
#               'girls',
#               'girls',
#               'sand',
#               'sand',
#               'sand',
#               'sand'],
#              '1572532018_64c030c974.jpg': ['children',
#               'boys',
#               'boys',
#               'boys',
#               'shorts',
#               'water'],
#              '1917265421_aeccf1ca38.jpg': ['children', 'children', 'children'],
#              '2105756457_a100d8434e.jpg': ['children', 'men', 'table'],
#              '2189995738_352607a63b.jpg': ['children', 'children', 'water'],
#              '2194286203_5dc620006a.jpg': ['children',
#               'sand',
#               'sand',
#               'sand',
#               'sand',
#               'sand',
#               'building'],
#              '2228022180_9597b2a458.jpg': ['children',
#               'children',
#               'children',
#               'children',
#               'children'],
#              '2271755053_e1b1ec8442.jpg': ['children',
#               'basketball',
#               'basketball',
#               'basketball',
#               'basketball',
#               'basketball',
#               'shorts'],
#              '2288099178_41091aa00c.jpg': ['children', 'boys', 'boys', 'boys'],
#              '2470486377_c3a39ccb7b.jpg': ['children',
#               'boys',
#               'grass',
#               'field'],
#              '2498897831_0bbb5d5b51.jpg': ['children',
#               'girls',
#               'girls',
#               'girls',
#               'girls',
#               'swing',
#               'swing',
#               'bench',
#               'bench',
#               'bench',
#               'park'],
#              '2689001252_e0016c89f0.jpg': ['children',
#               'girls',
#               'girls',
#               'building'],
#              '2905942129_2b4bf59bc0.jpg': ['children',
#               'children',
#               'boys',
#               'swing',
#               'swing',
#               'swing',
#               'swing',
#               'swing',
#               'park'],
#              '2913965136_2d00136697.jpg': ['children',
#               'boys',
#               'soccer',
#               'soccer',
#               'soccer',
#               'soccer',
#               'soccer'],
#              '3025549604_38b86198f5.jpg': ['children',
#               'children',
#               'children',
#               'children'],
#              '3052196390_c59dd24ca8.jpg': ['children', 'children'],
#              '3072114570_e1c0127529.jpg': ['children',
#               'bike',
#               'bike',
#               'bike',
#               'boys',
#               'street'],
#              '200771289_31902164a7.jpg': ['men',
#               'men',
#               'men',
#               'men',
#               'camera',
#               'sunglasses'],
#              '2102360862_264452db8e.jpg': ['men', 'sunglasses'],
#              '2196316998_3b2d63f01f.jpg': ['men', 'men'],
#              '2229179070_dc8ea8582e.jpg': ['men'],
#              '2308978137_bfe776d541.jpg': ['men', 'boys'],
#              '241345905_5826a72da1.jpg': ['men',
#               'men',
#               'player',
#               'player',
#               'player',
#               'player',
#               'football',
#               'football',
#               'football',
#               'football',
#               'field',
#               'field'],
#              '241346971_c100650320.jpg': ['men',
#               'player',
#               'player',
#               'football',
#               'football',
#               'football',
#               'football',
#               'field'],
#              '2526585002_10987a63f3.jpg': ['men', 'men', 'men', 'men', 'men'],
#              '2610447973_89227ff978.jpg': ['men'],
#              '2815256108_fc1302117d.jpg': ['men',
#               'men',
#               'men',
#               'men',
#               'men',
#               'street'],
#              '2856080862_95d793fa9d.jpg': ['men',
#               'men',
#               'soccer',
#               'park',
#               'park',
#               'park'],
#              '2884420269_225d27f242.jpg': ['men',
#               'men',
#               'men',
#               'men',
#               'street'],
#              '2894217628_f1a4153dca.jpg': ['men',
#               'player',
#               'player',
#               'swing',
#               'football',
#               'football',
#               'football',
#               'football',
#               'football'],
#              '2926595608_69b22be8d4.jpg': ['men',
#               'men',
#               'men',
#               'basketball',
#               'basketball',
#               'basketball',
#               'basketball'],
#              '3045613316_4e88862836.jpg': ['men', 'men', 'mountain', 'ocean'],
#              '1446053356_a924b4893f.jpg': ['girls',
#               'girls',
#               'girls',
#               'player',
#               'field',
#               'field',
#               'field',
#               'field',
#               'soccer',
#               'soccer'],
#              '1467533293_a2656cc000.jpg': ['girls',
#               'girls',
#               'girls',
#               'girls',
#               'girls',
#               'park'],
#              '2339106348_2df90aa6a9.jpg': ['girls', 'girls', 'girls', 'hair'],
#              '2396691909_6b8c2f7c44.jpg': ['girls', 'dress', 'dress'],
#              '2445283938_ff477c7952.jpg': ['girls', 'girls', 'girls', 'girls'],
#              '2453971388_76616b6a82.jpg': ['girls',
#               'girls',
#               'girls',
#               'girls',
#               'girls',
#               'pool',
#               'pool',
#               'pool',
#               'pool'],
#              '2715035273_8fc8b1291c.jpg': ['girls',
#               'boys',
#               'street',
#               'street',
#               'street'],
#              '2075321027_c8fcbaf581.jpg': ['bike', 'street'],
#              '219070971_ae43410b9e.jpg': ['bike',
#               'bike',
#               'bike',
#               'bike',
#               'rock',
#               'rock',
#               'rock',
#               'dirt',
#               'dirt',
#               'dirt'],
#              '2497420371_74788d7ba1.jpg': ['bike',
#               'bike',
#               'building',
#               'building'],
#              '2544182005_3aa1332bf9.jpg': ['bike',
#               'bike',
#               'bike',
#               'bike',
#               'bike'],
#              '2577972703_a22c5f2a87.jpg': ['bike',
#               'dirt',
#               'face',
#               'face',
#               'face'],
#              '2581066814_179d28f306.jpg': ['bike', 'street'],
#              '2764178773_d63b502812.jpg': ['bike', 'air', 'mountain'],
#              '2813992915_f732cf8539.jpg': ['bike', 'bike'],
#              '2866254827_9a8f592017.jpg': ['bike'],
#              '2891617125_f939f604c7.jpg': ['bike',
#               'bike',
#               'bike',
#               'bike',
#               'dirt',
#               'dirt',
#               'dirt',
#               'dirt'],
#              '2902269566_419d9f1d8e.jpg': ['bike',
#               'bike',
#               'air',
#               'air',
#               'dirt',
#               'dirt'],
#              '2924259848_effb4dcb82.jpg': ['bike',
#               'bike',
#               'dirt',
#               'dirt',
#               'dirt',
#               'dirt',
#               'dirt'],
#              '2932740428_b15384f389.jpg': ['bike',
#               'jacket',
#               'dirt',
#               'dirt',
#               'dirt'],
#              '2949982320_c704b31626.jpg': ['bike', 'wall', 'building', 'park'],
#              '3192069971_83c5a90b4c.jpg': ['bike', 'bike'],
#              '2435685480_a79d42e564.jpg': ['rock',
#               'rock',
#               'rock',
#               'jacket',
#               'bench'],
#              '2554081584_233bdf289a.jpg': ['rock', 'rock', 'rock', 'rock'],
#              '2759860913_f75b39d783.jpg': ['rock',
#               'rock',
#               'jacket',
#               'mountain',
#               'mountain',
#               'mountain'],
#              '3016606751_0e8be20abd.jpg': ['rock', 'air', 'air', 'mountain'],
#              '3040033126_9f4b88261b.jpg': ['rock', 'rock', 'rock'],
#              '309687244_4bdf3b591f.jpg': ['rock',
#               'rock',
#               'rock',
#               'rock',
#               'rock',
#               'wall',
#               'wall',
#               'shorts',
#               'face'],
#              '3119875880_22f9129a1c.jpg': ['rock', 'rock', 'boys'],
#              '3244470342_c08f6bb17e.jpg': ['rock', 'wall'],
#              '3315616181_15dd137e27.jpg': ['rock',
#               'wall',
#               'wall',
#               'wall',
#               'wall'],
#              '1339596997_8ac29c1841.jpg': ['camera',
#               'camera',
#               'head',
#               'head',
#               'head',
#               'head'],
#              '2206960564_325ed0c7ae.jpg': ['camera'],
#              '2225231022_1632d0a5aa.jpg': ['camera', 'camera'],
#              '2346401538_f5e8da66fc.jpg': ['camera',
#               'camera',
#               'camera',
#               'camera',
#               'hat',
#               'jacket'],
#              '2473791980_805c819bd4.jpg': ['camera', 'ocean'],
#              '2496370758_a3fbc49837.jpg': ['camera', 'field', 'field'],
#              '2588927489_f4da2f11ec.jpg': ['camera',
#               'camera',
#               'hat',
#               'swing',
#               'park'],
#              '2696866120_254a0345bc.jpg': ['camera', 'dirt', 'dirt', 'dirt'],
#              '270724499_107481c88f.jpg': ['camera',
#               'field',
#               'mouth',
#               'mouth',
#               'mouth'],
#              '2718495608_d8533e3ac5.jpg': ['camera',
#               'sunglasses',
#               'sunglasses',
#               'sunglasses',
#               'sunglasses',
#               'sunglasses'],
#              '2774554310_007e980a90.jpg': ['camera'],
#              '2878190821_6e4e03dc5f.jpg': ['camera',
#               'swing',
#               'sunglasses',
#               'sunglasses',
#               'sunglasses',
#               'head',
#               'dirt',
#               'dirt'],
#              '2928152792_b16c73434a.jpg': ['camera', 'soccer', 'soccer'],
#              '2985679744_75a7102aab.jpg': ['camera', 'face'],
#              '3047264346_e24601bfbf.jpg': ['camera', 'sunglasses'],
#              '3070011270_390e597783.jpg': ['camera', 'camera', 'face', 'face'],
#              '307327914_f98f576adb.jpg': ['camera'],
#              '3079787482_0757e9d167.jpg': ['camera'],
#              '3114944484_28b5bb9842.jpg': ['camera', 'camera', 'face'],
#              '3116769029_f5a76f04ba.jpg': ['camera', 'jacket'],
#              '3121521593_18f0ec14f7.jpg': ['camera', 'head', 'dress'],
#              '3167365436_c379bda282.jpg': ['camera', 'head'],
#              '2373234213_4ebe9c4ee5.jpg': ['boys'],
#              '2460797929_66446c13db.jpg': ['boys', 'boys'],
#              '2594042571_2e4666507e.jpg': ['boys', 'hat', 'hat', 'hat', 'hat'],
#              '2646116932_232573f030.jpg': ['boys', 'table', 'table', 'park'],
#              '2707873672_15e6b5d54b.jpg': ['boys',
#               'boys',
#               'boys',
#               'boys',
#               'boys',
#               'hair',
#               'table',
#               'table',
#               'bench'],
#              '2729655904_1dd01922fb.jpg': ['boys',
#               'boys',
#               'boys',
#               'boys',
#               'ocean',
#               'sand'],
#              '279728508_6bd7281f3c.jpg': ['boys', 'boys'],
#              '2843695880_eeea6c67db.jpg': ['boys', 'ocean', 'ocean'],
#              '2844018783_524b08e5aa.jpg': ['boys',
#               'boys',
#               'boys',
#               'boys',
#               'boys',
#               'building',
#               'building'],
#              '3072172967_630e9c69d0.jpg': ['boys',
#               'player',
#               'basketball',
#               'basketball',
#               'basketball',
#               'basketball'],
#              '3217266166_4e0091860b.jpg': ['boys'],
#              '3217910740_d1d61c08ab.jpg': ['boys'],
#              '2078311270_f01c9eaf4c.jpg': ['hat', 'street', 'street'],
#              '2162564553_96de62c7e6.jpg': ['hat',
#               'hat',
#               'hat',
#               'hat',
#               'shorts',
#               'water',
#               'ocean'],
#              '2167644298_100ca79f54.jpg': ['hat',
#               'hat',
#               'hat',
#               'hat',
#               'hat',
#               'jacket',
#               'jacket',
#               'wall',
#               'wall',
#               'wall'],
#              '2218609886_892dcd6915.jpg': ['hat',
#               'hat',
#               'hat',
#               'wall',
#               'head',
#               'building',
#               'building'],
#              '2553550034_5901aa9d6c.jpg': ['hat', 'hat'],
#              '2559503010_84f20b3bc9.jpg': ['hat', 'hat', 'car'],
#              '2621415349_ef1a7e73be.jpg': ['hat',
#               'hat',
#               'sunglasses',
#               'sunglasses',
#               'sunglasses',
#               'mouth',
#               'mouth',
#               'mouth',
#               'mouth'],
#              '2652522323_9218afd8c2.jpg': ['hat', 'dress', 'park'],
#              '241345811_46b5f157d4.jpg': ['player',
#               'player',
#               'player',
#               'player',
#               'player',
#               'football',
#               'football',
#               'football',
#               'football',
#               'football',
#               'field'],
#              '241345844_69e1c22464.jpg': ['player',
#               'player',
#               'player',
#               'player',
#               'football',
#               'football',
#               'football',
#               'football'],
#              '241347204_007d83e252.jpg': ['player',
#               'football',
#               'football',
#               'football'],
#              '2933637854_984614e18b.jpg': ['player',
#               'player',
#               'player',
#               'football',
#               'football',
#               'football',
#               'football',
#               'football'],
#              '2994179598_a45c2732b5.jpg': ['player',
#               'player',
#               'basketball',
#               'basketball',
#               'basketball'],
#              '3125309108_1011486589.jpg': ['player', 'soccer', 'soccer'],
#              '3154641421_d1b9b8c24c.jpg': ['player',
#               'player',
#               'player',
#               'player',
#               'basketball',
#               'basketball',
#               'basketball',
#               'basketball'],
#              '3155451946_c0862c70cb.jpg': ['player',
#               'basketball',
#               'basketball',
#               'basketball',
#               'basketball',
#               'basketball'],
#              '3217620013_8b17873273.jpg': ['player',
#               'player',
#               'basketball',
#               'basketball',
#               'basketball',
#               'basketball'],
#              '3218480482_66af7587c8.jpg': ['player',
#               'player',
#               'player',
#               'basketball',
#               'basketball',
#               'basketball',
#               'basketball',
#               'basketball'],
#              '3222055946_45f7293bb2.jpg': ['player',
#               'player',
#               'basketball',
#               'basketball',
#               'basketball'],
#              '3232470286_903a61ea16.jpg': ['player',
#               'player',
#               'soccer',
#               'soccer',
#               'soccer',
#               'soccer',
#               'soccer'],
#              '3234115903_f4dfc8fc75.jpg': ['player'],
#              '3259666643_ae49524c81.jpg': ['player', 'player'],
#              '3290105461_7590f23371.jpg': ['player'],
#              '3301811927_a2797339e5.jpg': ['player'],
#              '3317073508_7e13565c1b.jpg': ['player',
#               'soccer',
#               'soccer',
#               'soccer',
#               'soccer'],
#              '172097782_f0844ec317.jpg': ['jacket'],
#              '2089426086_7acc98a3a8.jpg': ['jacket', 'jacket'],
#              '2207244634_1db1a1890b.jpg': ['jacket', 'park', 'park'],
#              '2247889670_413db8094b.jpg': ['jacket', 'jacket'],
#              '2518508760_68d8df7365.jpg': ['jacket'],
#              '2641770481_c98465ff35.jpg': ['jacket',
#               'jacket',
#               'jacket',
#               'jacket',
#               'ocean'],
#              '3006093003_c211737232.jpg': ['jacket'],
#              '302983277_69a4e732e4.jpg': ['jacket', 'mountain'],
#              '3044536048_e615466e7f.jpg': ['jacket', 'ocean', 'ocean'],
#              '3080056515_3013830309.jpg': ['jacket', 'hair'],
#              '3192266178_f9bf5d3dba.jpg': ['jacket', 'park'],
#              '3213992947_3f3f967a9f.jpg': ['jacket', 'jacket', 'jacket'],
#              '3258874419_23fec1bdc1.jpg': ['jacket'],
#              '3275704430_a75828048f.jpg': ['jacket',
#               'hair',
#               'park',
#               'face',
#               'face'],
#              '3287549827_04dec6fb6e.jpg': ['jacket'],
#              '3348385580_10b53391f9.jpg': ['jacket', 'jacket', 'wall'],
#              '3359530430_249f51972c.jpg': ['jacket'],
#              '3393926562_66cc01b001.jpg': ['jacket',
#               'jacket',
#               'jacket',
#               'hair',
#               'sunglasses'],
#              '3429956016_3c7e3096c2.jpg': ['jacket',
#               'wall',
#               'mountain',
#               'mountain',
#               'face'],
#              '2251747182_6b67a3ab8b.jpg': ['basketball',
#               'basketball',
#               'basketball',
#               'basketball',
#               'shorts'],
#              '3053743109_a2d780c0d2.jpg': ['basketball',
#               'basketball',
#               'basketball',
#               'basketball'],
#              '2447284966_d6bbdb4b6e.jpg': ['swing'],
#              '2458269558_277012780d.jpg': ['swing', 'swing', 'swing', 'swing'],
#              '2774430374_fee1d793e7.jpg': ['swing', 'shorts'],
#              '3399284917_721aefe2a7.jpg': ['swing',
#               'swing',
#               'swing',
#               'swing',
#               'swing'],
#              '3453259666_9ecaa8bb4b.jpg': ['swing', 'park'],
#              '1679617928_a73c1769be.jpg': ['car'],
#              '2421446839_fe7d46c177.jpg': ['car', 'car', 'car', 'car', 'face'],
#              '2533424347_cf2f84872b.jpg': ['car', 'car', 'car', 'car', 'car'],
# ...
#               'sunglasses',
#               'sunglasses',
#               'sunglasses',
#               'sunglasses'],
#              '3718964174_cb2dc1615e.jpg': ['sunglasses',
#               'head',
#               'head',
#               'head',
#               'head'],
#              '506738508_327efdf9c3.jpg': ['sunglasses',
#               'sunglasses',
#               'sunglasses'],
#              '700884207_d3ec546494.jpg': ['sunglasses',
#               'sunglasses',
#               'sunglasses',
#               'sunglasses'],
#              '2484190118_e89363c465.jpg': ['head',
#               'head',
#               'head',
#               'shorts',
#               'shorts',
#               'shorts',
#               'street',
#               'park'],
#              '2521770311_3086ca90de.jpg': ['head',
#               'head',
#               'head',
#               'head',
#               'head'],
#              '300550441_f44ec3701a.jpg': ['head', 'park'],
#              '3051384385_c5c850c1f8.jpg': ['head', 'head'],
#              '311146855_0b65fdb169.jpg': ['head'],
#              '3201427741_3033f5b625.jpg': ['head'],
#              '3208074567_ac44aeb3f3.jpg': ['head'],
#              '3211556865_d1d9becf69.jpg': ['head',
#               'mountain',
#               'mountain',
#               'mountain',
#               'mountain'],
#              '3259991972_fce3ab18b2.jpg': ['head', 'head', 'head', 'head'],
#              '3360930596_1e75164ce6.jpg': ['head',
#               'head',
#               'head',
#               'shorts',
#               'shorts',
#               'soccer',
#               'soccer',
#               'soccer',
#               'soccer'],
#              '476759700_8911f087f8.jpg': ['head'],
#              '491405109_798222cfd0.jpg': ['head', 'head', 'head', 'face'],
#              '57422853_b5f6366081.jpg': ['head', 'head'],
#              '2501595799_6316001e89.jpg': ['shorts',
#               'pool',
#               'pool',
#               'pool',
#               'pool',
#               'pool'],
#              '2533642917_a5eace85e6.jpg': ['shorts'],
#              '260520547_944f9f4c91.jpg': ['shorts', 'dress'],
#              '2682382530_f9f8fd1e89.jpg': ['shorts', 'shorts', 'air'],
#              '2693425189_47740c22ed.jpg': ['shorts',
#               'pool',
#               'pool',
#               'pool',
#               'pool'],
#              '2806710650_e201acd913.jpg': ['shorts', 'shorts'],
#              '3027397797_4f1d305ced.jpg': ['shorts',
#               'shorts',
#               'shorts',
#               'street',
#               'street',
#               'street',
#               'ocean'],
#              '3187492926_8aa85f80c6.jpg': ['shorts'],
#              '3238951136_2a99f1a1a8.jpg': ['shorts', 'shorts'],
#              '3256275785_9c3af57576.jpg': ['shorts'],
#              '3358682439_be4b83544c.jpg': ['shorts', 'park', 'park'],
#              '3359551687_68f2f0212a.jpg': ['shorts'],
#              '3413571342_b9855795e2.jpg': ['shorts'],
#              '3430607596_7e4f74e3ff.jpg': ['shorts', 'shorts'],
#              '3497224764_6e17544e0d.jpg': ['shorts'],
#              '3544793763_b38546a5e8.jpg': ['shorts', 'shorts'],
#              '3677318686_b018862bb7.jpg': ['shorts'],
#              '3745451546_fc8ec70cbd.jpg': ['shorts'],
#              '224369028_b1ac40d1fa.jpg': ['dress', 'dress', 'park'],
#              '2991994415_504d1c0a03.jpg': ['dress', 'dress'],
#              '3145967309_b33abe4d84.jpg': ['dress', 'dress'],
#              '3246991821_750a3097e2.jpg': ['dress', 'dress', 'dress'],
#              '3433982387_3fa993cf5a.jpg': ['dress', 'dress'],
#              '3538213870_9856a76b2a.jpg': ['dress',
#               'dress',
#               'dress',
#               'dress',
#               'dress'],
#              '3569406219_f37ebf7b92.jpg': ['dress'],
#              '3589367895_5d3729e3ea.jpg': ['dress'],
#              '3655964639_21e76383d0.jpg': ['dress', 'dress', 'dress'],
#              '3688858505_e8afd1475d.jpg': ['dress',
#               'dress',
#               'dress',
#               'dress',
#               'dress'],
#              '3767841911_6678052eb6.jpg': ['dress',
#               'dress',
#               'dress',
#               'dress',
#               'dress'],
#              '540721368_12ac732c6c.jpg': ['dress', 'dress'],
#              '751109943_2a7f8e117f.jpg': ['dress'],
#              '758921886_55a351dd67.jpg': ['dress'],
#              '766099402_cdda6964f0.jpg': ['dress', 'dress', 'dress', 'face'],
#              '2431470169_0eeba7d602.jpg': ['table', 'table', 'table'],
#              '2495931537_9b8d4474b6.jpg': ['table'],
#              '2529116152_4331dabf50.jpg': ['table', 'building'],
#              '2602258549_7401a3cdae.jpg': ['table', 'table', 'table'],
#              '2675685200_0913d84d9b.jpg': ['table',
#               'table',
#               'table',
#               'table',
#               'table'],
#              '2842865689_e37256d9ce.jpg': ['table', 'table', 'table'],
#              '3042380610_c5ea61eef8.jpg': ['table'],
#              '3099923914_fd450f6d51.jpg': ['table',
#               'table',
#               'table',
#               'building',
#               'building',
#               'building',
#               'building'],
#              '3243588540_b418ac7eda.jpg': ['table'],
#              '3295391572_cbfde03a10.jpg': ['table',
#               'table',
#               'building',
#               'building'],
#              '3393343330_b13df4d8ec.jpg': ['table', 'table', 'table'],
#              '339658315_fbb178c252.jpg': ['table',
#               'table',
#               'building',
#               'building',
#               'building'],
#              '3462454965_a481809cea.jpg': ['table'],
#              '3597326009_3678a98a43.jpg': ['table', 'table', 'table', 'bench'],
#              '3741462565_cc35966b7a.jpg': ['table'],
#              '533713007_bf9f3e25b4.jpg': ['table', 'table', 'table', 'table'],
#              '979383193_0a542a059d.jpg': ['table', 'table'],
#              '166507476_9be5b9852a.jpg': ['water', 'water', 'water'],
#              '1772859261_236c09b861.jpg': ['water', 'water', 'water', 'water'],
#              '1808370027_2088394eb4.jpg': ['water'],
#              '2101457132_69c950bc45.jpg': ['water'],
#              '2103568100_5d018c495b.jpg': ['water', 'water', 'mountain'],
#              '211295363_49010ca38d.jpg': ['water'],
#              '1659358141_0433c9bf99.jpg': ['grass', 'grass', 'grass'],
#              '1674612291_7154c5ab61.jpg': ['grass'],
#              '2170222061_e8bce4a32d.jpg': ['grass', 'face', 'face'],
#              '2280525192_81911f2b00.jpg': ['grass',
#               'grass',
#               'grass',
#               'field',
#               'field'],
#              '229862312_1a0ba19dab.jpg': ['grass',
#               'grass',
#               'grass',
#               'grass',
#               'grass'],
#              '2300168895_a9b83e16fc.jpg': ['grass',
#               'grass',
#               'grass',
#               'grass',
#               'grass'],
#              '2358898017_24496b80e8.jpg': ['grass', 'grass', 'field'],
#              '245895500_a4eb97af02.jpg': ['grass'],
#              '246055693_ccb69ac5c6.jpg': ['grass'],
#              '2301525531_edde12d673.jpg': ['bench',
#               'snow',
#               'snow',
#               'snow',
#               'snow',
#               'park',
#               'park'],
#              '3106026005_473a7b1c8c.jpg': ['bench',
#               'bench',
#               'bench',
#               'bench',
#               'bench',
#               'street'],
#              '324208502_674488bcea.jpg': ['bench',
#               'bench',
#               'bench',
#               'bench',
#               'bench'],
#              '3471841031_a949645ba8.jpg': ['bench',
#               'bench',
#               'bench',
#               'park',
#               'park',
#               'park'],
#              '3482062809_3b694322c4.jpg': ['bench', 'bench'],
#              '373394550_1b2296b8c4.jpg': ['bench', 'bench'],
#              '532457586_bddfc5251d.jpg': ['bench',
#               'bench',
#               'bench',
#               'bench',
#               'bench'],
#              '561940436_64d6fc125d.jpg': ['bench', 'bench', 'bench', 'bench'],
#              '113678030_87a6a6e42e.jpg': ['snow'],
#              '2100816230_ff866fb352.jpg': ['snow', 'snow', 'air'],
#              '2285570521_05015cbf4b.jpg': ['snow', 'snow'],
#              '2374652725_32f90fa15c.jpg': ['snow'],
#              '2295750198_6d152d7ceb.jpg': ['air', 'field', 'field'],
#              '2450453051_f1d4a78ab4.jpg': ['air', 'mouth'],
#              '2461616306_3ee7ac1b4b.jpg': ['air',
#               'pool',
#               'pool',
#               'pool',
#               'pool',
#               'pool'],
#              '2594902417_f65d8866a8.jpg': ['air',
#               'field',
#               'field',
#               'field',
#               'field',
#               'field'],
#              '2646046871_c3a5dbb971.jpg': ['air', 'air', 'building'],
#              '2718024196_3ff660416a.jpg': ['air', 'air', 'pool'],
#              '2731171552_4a808c7d5a.jpg': ['air', 'air'],
#              '2813033949_e19fa08805.jpg': ['air'],
#              '2854959952_3991a385ab.jpg': ['air', 'field'],
#              '2868575889_2c030aa8ae.jpg': ['air',
#               'street',
#               'street',
#               'street'],
#              '2892995070_39f3c9a56e.jpg': ['air'],
#              '2901880865_3fd7b66a45.jpg': ['air'],
#              '2944362789_aebbc22db4.jpg': ['air', 'park', 'park'],
#              '2945036454_280fa5b29f.jpg': ['air'],
#              '2953015871_cae796b6e7.jpg': ['air'],
#              '2971431335_e192613db4.jpg': ['air', 'air'],
#              '300314926_0b2e4b64f5.jpg': ['air', 'air', 'air', 'air'],
#              '3024172109_a10198e1dd.jpg': ['air', 'air'],
#              '249394748_2e4acfbbb5.jpg': ['field', 'field'],
#              '2534502836_7a75305655.jpg': ['field'],
#              '2573625591_70291c894a.jpg': ['field', 'field', 'building'],
#              '2600867924_cd502fc911.jpg': ['field', 'field'],
#              '261490838_2f3ac98b12.jpg': ['field', 'field', 'field'],
#              '2763044275_aa498eb88b.jpg': ['field', 'field'],
#              '2854207034_1f00555703.jpg': ['field', 'field'],
#              '2248487950_c62d0c81a9.jpg': ['street', 'street', 'street'],
#              '245252561_4f20f1c89e.jpg': ['street', 'street'],
#              '2698666984_13e17236ae.jpg': ['street'],
#              '2910758605_73a3f5a5c2.jpg': ['street'],
#              '3061481868_d1e00b1f2e.jpg': ['street'],
#              '2525270674_4ab536e7ec.jpg': ['mouth', 'mouth', 'mouth'],
#              '2543589122_ec3e55f434.jpg': ['mouth', 'mouth', 'pool', 'pool'],
#              '256085101_2c2617c5d0.jpg': ['mouth', 'mouth', 'mouth'],
#              '2616643090_4f2d2d1a44.jpg': ['mouth', 'mouth', 'mouth', 'mouth'],
#              '2647049174_0fb47cee2e.jpg': ['mouth',
#               'mouth',
#               'mouth',
#               'dirt',
#               'dirt',
#               'dirt',
#               'dirt',
#               'dirt'],
#              '280706862_14c30d734a.jpg': ['mouth',
#               'mouth',
#               'mouth',
#               'mouth',
#               'mouth',
#               'sand'],
#              '2839038702_e168128665.jpg': ['mouth',
#               'mouth',
#               'mouth',
#               'mountain'],
#              '2480850054_de3433b54a.jpg': ['dirt',
#               'dirt',
#               'dirt',
#               'dirt',
#               'dirt'],
#              '2649406158_ded6be38de.jpg': ['dirt', 'dirt'],
#              '2683963310_20dcd5e566.jpg': ['dirt', 'dirt', 'sand', 'sand'],
#              '2822290399_97c809d43b.jpg': ['dirt', 'dirt', 'dirt'],
#              '2893374123_087f98d58a.jpg': ['dirt'],
#              '2112921744_92bf706805.jpg': ['mountain'],
#              '2657484284_daa07a3a1b.jpg': ['mountain'],
#              '2950905787_f2017d3e49.jpg': ['mountain', 'mountain'],
#              '3139876823_859c7d7c23.jpg': ['mountain'],
#              '3159995270_17334ccb5b.jpg': ['mountain'],
#              '3299820401_c2589186c5.jpg': ['mountain', 'mountain', 'mountain'],
#              '3301859683_2d5e4b40a3.jpg': ['mountain'],
#              '3334537556_a2cf4e9b9a.jpg': ['mountain'],
#              '3364026240_645d533fda.jpg': ['mountain', 'mountain', 'mountain'],
#              '2450299735_62c095f40e.jpg': ['pool', 'pool', 'pool', 'pool'],
#              '2549968784_39bfbe44f9.jpg': ['pool', 'pool', 'pool'],
#              '2599444370_9e40103027.jpg': ['pool', 'pool', 'pool', 'pool'],
#              '2660008870_b672a4c76a.jpg': ['pool',
#               'pool',
#               'pool',
#               'pool',
#               'pool'],
#              '2196846255_2c1635359a.jpg': ['ocean', 'ocean'],
#              '2559921948_06af25d566.jpg': ['ocean'],
#              '2663794355_e726ec7e05.jpg': ['ocean'],
#              '2708686056_1b8f356264.jpg': ['ocean', 'ocean'],
#              '2830869109_c4e403eae6.jpg': ['ocean'],
#              '2870875612_2cbb9e4a3c.jpg': ['ocean'],
#              '2938747424_64e64784f0.jpg': ['ocean', 'ocean'],
#              '2984174290_a915748d77.jpg': ['ocean'],
#              '3085667865_fa001816be.jpg': ['ocean'],
#              '3149919755_f9272b10b3.jpg': ['ocean'],
#              '3162045919_c2decbb69b.jpg': ['ocean'],
#              '3168123064_d1983b8f92.jpg': ['ocean'],
#              '3185409663_95f6b958d8.jpg': ['ocean', 'ocean', 'ocean'],
#              '3225310099_d8e419ba56.jpg': ['ocean'],
#              '2295216243_0712928988.jpg': ['sand', 'sand'],
#              '2589241160_3832440850.jpg': ['sand', 'sand'],
#              '2782433864_5a0c311d87.jpg': ['sand', 'sand'],
#              '2844641033_dab3715a99.jpg': ['sand',
#               'sand',
#               'sand',
#               'sand',
#               'sand'],
#              '2933912528_52b05f84a1.jpg': ['sand', 'sand', 'sand', 'sand'],
#              '300922408_05a4f9938c.jpg': ['sand'],
#              '3070031806_3d587c2a66.jpg': ['sand'],
#              '3123463486_f5b36a3624.jpg': ['sand'],
#              '3128164023_ebe8da4c32.jpg': ['sand', 'sand'],
#              '2575647360_f5de38c751.jpg': ['building'],
#              '2877503811_4e311253ec.jpg': ['building', 'building', 'building'],
#              '293327462_20dee0de56.jpg': ['building'],
#              '3100251515_c68027cc22.jpg': ['building'],
#              '3157847991_463e006a28.jpg': ['building', 'building'],
#              '3222041930_f642f49d28.jpg': ['building', 'building'],
#              '3234401637_84e0d14414.jpg': ['building'],
#              '3245912109_fdeef6b456.jpg': ['building', 'building', 'building'],
#              '3254817653_632e840423.jpg': ['building'],
#              '3332467180_d72f9b067d.jpg': ['building', 'building'],
#              '3432550415_e7b77232de.jpg': ['building'],
#              '3490736665_38710f4b91.jpg': ['building'],
#              '2885387575_9127ea10f1.jpg': ['soccer', 'soccer'],
#              '3545652636_0746537307.jpg': ['soccer', 'soccer', 'soccer'],
#              '3019842612_8501c1791e.jpg': ['park'],
#              '3138399980_d6ab8b2272.jpg': ['park'],
#              '3325497914_f9014d615b.jpg': ['park'],
#              '3435035138_af32890a4c.jpg': ['park'],
#              '3558370311_5734a15890.jpg': ['park'],
#              '3568197730_a071d7595b.jpg': ['park'],
#              '3589895574_ee08207d26.jpg': ['park'],
#              '3635577874_48ebaac734.jpg': ['park'],
#              '3657016761_d553e514d9.jpg': ['park', 'park'],
#              '2706766641_a9df81969d.jpg': ['face'],
#              '3203908917_53e53c03d1.jpg': ['face'],
#              '3214573346_d3a57f0328.jpg': ['face'],
#              '3250695024_93e8ab7305.jpg': ['face'],
#              '3364861247_d590fa170d.jpg': ['face'],
#              '3437654963_c4fdc17e8b.jpg': ['face'],
#              '3459156091_c1879ebe28.jpg': ['face'],
#              '3503623999_bbd5dcfb18.jpg': ['face', 'face', 'face'],
#              '3697359692_8a5cdbe4fe.jpg': ['face', 'face', 'face', 'face'],
#              '3741827382_71e93298d0.jpg': ['face'],
#              '488408004_a1e26d4886.jpg': ['face', 'face'],
#              '917574521_74fab68514.jpg': ['face'],
#              '997722733_0cb5439472.jpg': ['face']})

# %%
# #inefficient way to remove caption number from files for comparison
# file = captionfile.split('_', -1)[0:2]
# testword = "_".join(file)

# %%
with open('/Users/sebastiaanscholten/Documents/speech2image-master/vgsexperiments/experiments/data/finallistdict.json', 'w') as fp:
    json.dump(finallistdict, fp)

# %%
len(finallistdict)
# Out:
# 580

# %%
import pandas as pd
import ast
import statistics
import matplotlib.pyplot as plt
import numpy
import tables
from scipy.stats import spearmanr
from nltk.corpus import cmudict

# %%
path = "/Users/sebastiaanscholten/Documents/speech2image-master/vgsexperiments/experiments/Results_isolated_word_recognition/results_forcedalignment_phonemes.csv"
df = pd.read_csv(path)

# %%
df["Testedword"] = df["Tested"].str.replace("flickr_","")
df["Testedword"] = [words.split("_")[2] for words in df["Testedword"]]


df["Results"] = [ast.literal_eval(score) for score in df["Results"]]
df["Precision@10"] = [sum(score)*0.1 for score in df["Results"]]
df["AmntPhonemes"] = [int(words.split("_")[1]) for words in df["Tested"]]

# %%
scorelist = pd.DataFrame()
for i in range(1,max(df["AmntPhonemes"])+1):
    averagescore = sum(df[df["AmntPhonemes"] == i]["Precision@10"])/len(df[df["AmntPhonemes"] == i])
    valuesdict = {"Amntphonemes": i,"Nphonemes":len(df[df["AmntPhonemes"] == i]), "Avgscore": averagescore}
    scorelist = scorelist.append(valuesdict, ignore_index=True)

# %%
scorelist
# Out:
#    Amntphonemes  Avgscore  Nphonemes
# 0           1.0  0.109959     1446.0
# 1           2.0  0.286863     1393.0
# 2           3.0  0.357185     1350.0
# 3           4.0  0.370654      719.0
# 4           5.0  0.350538      372.0
# 5           6.0  0.421081      185.0
# 6           7.0  0.507143      140.0
# 7           8.0  0.676842       95.0
# 8           9.0  0.683158       95.0

# %%
testlist = ["dog","man","boy","girl","woman","people"
            ,"dogs","shirt","child","ball","person"
            ,"children","men","girls","bike","rock","camera"
            ,"boys","hat","player","jacket","basketball","swing"
            ,"car", "wall", "hair","football","sunglasses","head"
            ,"shorts","dress","table"]
header_list = ["Word","1","2","3","4","5","6","7","8","9"]
df1 = pd.DataFrame()
df1["Word"] = [word for word in testlist]
df1 = df1.reindex(columns = header_list)

dfheatmap = pd.DataFrame()

for idx,word in enumerate(df1["Word"]):
    subdf = df[df["Testedword"] == word]
    for i in range(1,max(subdf["AmntPhonemes"])+1):
        averagescore = sum(subdf[subdf["AmntPhonemes"] == i]["Precision@10"])/len(subdf[subdf["AmntPhonemes"] == i])
        valuesdict = {"Words": word, "Length of phoneme sequence shown": i, "AvgScore": averagescore}
        dfheatmap = dfheatmap.append(valuesdict, ignore_index=True)
        df1[f"{i}"].iloc[idx] = averagescore

# %%
df1["Naan"] = df1.isnull().sum(axis=1)
df1 = df1.sort_values(by=["Naan"])
custom_order = list(df1["Word"])

# %%
import seaborn as sns
testheatmap = dfheatmap
dfheatmap = dfheatmap.pivot(index="Words",columns="Length of phoneme sequence shown",values="AvgScore")
dfheatmap = dfheatmap.reindex(custom_order, axis=0)

# %%
plt.figure(figsize=(10, 8))
ax = sns.heatmap(dfheatmap,cmap="Blues",xticklabels=True, yticklabels=True,linewidths=0,cbar_kws={'label': 'Precision@10'})
# ax = sns.heatmap(dfheatmap,cmap="YlOrRd",xticklabels=True, yticklabels=True,linewidths=0,cbar_kws={'label': 'Precision@10'})
ax.set_title('Image retrieval scores for all phoneme sequences')
plt.savefig('/Users/sebastiaanscholten/Documents/speech2image-master/vgsexperiments/experiments/plots/phonemeheatmap.png')

plt.show()

# %%
dfheatmap
# Out:
# Length of phoneme sequence shown       1.0       2.0       3.0       4.0  \
# Words
# basketball                        0.086000  0.014894  0.123404  0.225532
# sunglasses                        0.244898  0.043750  0.039583  0.016667
# children                          0.180000  0.195556  0.277778  0.328889
# football                          0.106122  0.046667  0.131111  0.322222
# person                            0.184783  0.021739  0.119565  0.136957
# camera                            0.044444  0.138889  0.205556  0.211111
# jacket                            0.002128  0.095745  0.217021  0.210638
# woman                             0.081081  0.043243  0.410811  0.583784
# shorts                            0.059524  0.364103  0.469231  0.448718
# people                            0.211628  0.246512  0.251163  0.525581
# child                             0.127273  0.415909  0.545455  0.556818
# player                            0.064151  0.169565  0.271739  0.378261
# girls                             0.079070  0.290698  0.334884  0.400000
# dress                             0.043182  0.077500  0.137500  0.340000
# swing                             0.004082  0.022500  0.427500  0.522500
# dogs                              0.020833  0.529167  0.625000  0.695833
# table                             0.011628  0.100000  0.130233  0.397674
# hair                              0.053488  0.079070  0.074419       NaN
# wall                              0.095556  0.275000  0.479545       NaN
# car                               0.363043  0.668182  0.634091       NaN
# head                              0.065957  0.080851  0.072340       NaN
# dog                               0.060000  0.693878  0.810204       NaN
# boys                              0.072000  0.183673  0.175510       NaN
# bike                              0.026667  0.316279  0.576744       NaN
# men                               0.179167  0.180851  0.138298       NaN
# ball                              0.148000  0.469565  0.447826       NaN
# shirt                             0.120000  0.509302  0.462791       NaN
# girl                              0.172500  0.547500  0.785000       NaN
# man                               0.267347  0.739583  0.808333       NaN
# hat                               0.105000  0.125000  0.167500       NaN
# rock                              0.030909  0.593750  0.639583       NaN
# boy                               0.183721  0.720930       NaN       NaN
#
# Length of phoneme sequence shown       5.0       6.0       7.0       8.0  \
# Words
# basketball                        0.504255  0.523404  0.768085  0.914894
# sunglasses                        0.020833  0.056250  0.329167  0.443750
# children                          0.426667  0.393333  0.424444       NaN
# football                          0.648889  0.731111       NaN       NaN
# person                            0.128261       NaN       NaN       NaN
# camera                            0.172222       NaN       NaN       NaN
# jacket                            0.238298       NaN       NaN       NaN
# woman                             0.586486       NaN       NaN       NaN
# shorts                            0.394872       NaN       NaN       NaN
# people                                 NaN       NaN       NaN       NaN
# child                                  NaN       NaN       NaN       NaN
# player                                 NaN       NaN       NaN       NaN
# girls                                  NaN       NaN       NaN       NaN
# dress                                  NaN       NaN       NaN       NaN
# swing                                  NaN       NaN       NaN       NaN
# dogs                                   NaN       NaN       NaN       NaN
# table                                  NaN       NaN       NaN       NaN
# hair                                   NaN       NaN       NaN       NaN
# wall                                   NaN       NaN       NaN       NaN
# car                                    NaN       NaN       NaN       NaN
# head                                   NaN       NaN       NaN       NaN
# dog                                    NaN       NaN       NaN       NaN
# boys                                   NaN       NaN       NaN       NaN
# bike                                   NaN       NaN       NaN       NaN
# men                                    NaN       NaN       NaN       NaN
# ball                                   NaN       NaN       NaN       NaN
# shirt                                  NaN       NaN       NaN       NaN
# girl                                   NaN       NaN       NaN       NaN
# man                                    NaN       NaN       NaN       NaN
# hat                                    NaN       NaN       NaN       NaN
# rock                                   NaN       NaN       NaN       NaN
# boy                                    NaN       NaN       NaN       NaN
#
# Length of phoneme sequence shown       9.0
# Words
# basketball                        0.904255
# sunglasses                        0.466667
# children                               NaN
# football                               NaN
# person                                 NaN
# camera                                 NaN
# jacket                                 NaN
# woman                                  NaN
# shorts                                 NaN
# people                                 NaN
# child                                  NaN
# player                                 NaN
# girls                                  NaN
# dress                                  NaN
# swing                                  NaN
# dogs                                   NaN
# table                                  NaN
# hair                                   NaN
# wall                                   NaN
# car                                    NaN
# head                                   NaN
# dog                                    NaN
# boys                                   NaN
# bike                                   NaN
# men                                    NaN
# ball                                   NaN
# shirt                                  NaN
# girl                                   NaN
# man                                    NaN
# hat                                    NaN
# rock                                   NaN
# boy                                    NaN

# %%
for word in testlist:
    testheatmap.loc[testheatmap["Words"] == word,"AvgScore"] = testheatmap[testheatmap["Words"] == word]["AvgScore"]/(testheatmap["AvgScore"][testheatmap[testheatmap["Words"] == word]["AvgScore"].idxmax()])

# %%
# testheatmap["AvgScore"] = [float(values) for values in testheatmap["AvgScore"]]
# # data.loc[data['name'] == 'fred', 'A']
# testheatmap.loc[testheatmap["Words"] == "dog","AvgScore"] = testheatmap[testheatmap["Words"] == "dog"]["AvgScore"]/(testheatmap["AvgScore"][testheatmap[testheatmap["Words"] == "dog"]["Amnt of Phonemes"].idxmax()])

# %%
testheatmap
dfheatmap = testheatmap.pivot(index="Words",columns="Length of phoneme sequence shown",values="AvgScore")
dfheatmap = dfheatmap.reindex(custom_order, axis=0)
plt.figure(figsize=(10, 8))
ax = sns.heatmap(dfheatmap,cmap="Blues",xticklabels=True, yticklabels=True,linewidths=0,cbar_kws={'label': 'Precision@10 / Highest phoneme cut Precision@10'})
# ax = sns.heatmap(dfheatmap,cmap="YlOrRd",xticklabels=True, yticklabels=True,linewidths=0,cbar_kws={'label': 'Precision@10'})
ax.set_title('Image retrieval scores for all phoneme sequences')
plt.savefig('/Users/sebastiaanscholten/Documents/speech2image-master/vgsexperiments/experiments/plots/phonemeheatmap_cut.png')

plt.show()

# %%
pd.set_option("display.max_rows", None, "display.max_columns", None)
testheatmap
# Out:
#      AvgScore  Length of phoneme sequence shown       Words
# 0    0.074055                               1.0         dog
# 1    0.856423                               2.0         dog
# 2    1.000000                               3.0         dog
# 3    0.330738                               1.0         man
# 4    0.914948                               2.0         man
# 5    1.000000                               3.0         man
# 6    0.254839                               1.0         boy
# 7    1.000000                               2.0         boy
# 8    0.219745                               1.0        girl
# 9    0.697452                               2.0        girl
# 10   1.000000                               3.0        girl
# 11   0.138249                               1.0       woman
# 12   0.073733                               2.0       woman
# 13   0.700461                               3.0       woman
# 14   0.995392                               4.0       woman
# 15   1.000000                               5.0       woman
# 16   0.402655                               1.0      people
# 17   0.469027                               2.0      people
# 18   0.477876                               3.0      people
# 19   1.000000                               4.0      people
# 20   0.029940                               1.0        dogs
# 21   0.760479                               2.0        dogs
# 22   0.898204                               3.0        dogs
# 23   1.000000                               4.0        dogs
# 24   0.235616                               1.0       shirt
# 25   1.000000                               2.0       shirt
# 26   0.908676                               3.0       shirt
# 27   0.228571                               1.0       child
# 28   0.746939                               2.0       child
# 29   0.979592                               3.0       child
# 30   1.000000                               4.0       child
# 31   0.315185                               1.0        ball
# 32   1.000000                               2.0        ball
# 33   0.953704                               3.0        ball
# 34   1.000000                               1.0      person
# 35   0.117647                               2.0      person
# 36   0.647059                               3.0      person
# 37   0.741176                               4.0      person
# 38   0.694118                               5.0      person
# 39   0.421875                               1.0    children
# 40   0.458333                               2.0    children
# 41   0.651042                               3.0    children
# 42   0.770833                               4.0    children
# 43   1.000000                               5.0    children
# 44   0.921875                               6.0    children
# 45   0.994792                               7.0    children
# 46   0.990686                               1.0         men
# 47   1.000000                               2.0         men
# 48   0.764706                               3.0         men
# 49   0.197674                               1.0       girls
# 50   0.726744                               2.0       girls
# 51   0.837209                               3.0       girls
# 52   1.000000                               4.0       girls
# 53   0.046237                               1.0        bike
# 54   0.548387                               2.0        bike
# 55   1.000000                               3.0        bike
# 56   0.048327                               1.0        rock
# 57   0.928339                               2.0        rock
# 58   1.000000                               3.0        rock
# 59   0.210526                               1.0      camera
# 60   0.657895                               2.0      camera
# 61   0.973684                               3.0      camera
# 62   1.000000                               4.0      camera
# 63   0.815789                               5.0      camera
# 64   0.392000                               1.0        boys
# 65   1.000000                               2.0        boys
# 66   0.955556                               3.0        boys
# 67   0.626866                               1.0         hat
# 68   0.746269                               2.0         hat
# 69   1.000000                               3.0         hat
# 70   0.169594                               1.0      player
# 71   0.448276                               2.0      player
# 72   0.718391                               3.0      player
# 73   1.000000                               4.0      player
# 74   0.008929                               1.0      jacket
# 75   0.401786                               2.0      jacket
# 76   0.910714                               3.0      jacket
# 77   0.883929                               4.0      jacket
# 78   1.000000                               5.0      jacket
# 79   0.094000                               1.0  basketball
# 80   0.016279                               2.0  basketball
# 81   0.134884                               3.0  basketball
# 82   0.246512                               4.0  basketball
# 83   0.551163                               5.0  basketball
# 84   0.572093                               6.0  basketball
# 85   0.839535                               7.0  basketball
# 86   1.000000                               8.0  basketball
# 87   0.988372                               9.0  basketball
# 88   0.007812                               1.0       swing
# 89   0.043062                               2.0       swing
# 90   0.818182                               3.0       swing
# 91   1.000000                               4.0       swing
# 92   0.543330                               1.0         car
# 93   1.000000                               2.0         car
# 94   0.948980                               3.0         car
# 95   0.199263                               1.0        wall
# 96   0.573460                               2.0        wall
# 97   1.000000                               3.0        wall
# 98   0.676471                               1.0        hair
# 99   1.000000                               2.0        hair
# 100  0.941176                               3.0        hair
# 101  0.145152                               1.0    football
# 102  0.063830                               2.0    football
# 103  0.179331                               3.0    football
# 104  0.440729                               4.0    football
# 105  0.887538                               5.0    football
# 106  1.000000                               6.0    football
# 107  0.524781                               1.0  sunglasses
# 108  0.093750                               2.0  sunglasses
# 109  0.084821                               3.0  sunglasses
# 110  0.035714                               4.0  sunglasses
# 111  0.044643                               5.0  sunglasses
# 112  0.120536                               6.0  sunglasses
# 113  0.705357                               7.0  sunglasses
# 114  0.950893                               8.0  sunglasses
# 115  1.000000                               9.0  sunglasses
# 116  0.815789                               1.0        head
# 117  1.000000                               2.0        head
# 118  0.894737                               3.0        head
# 119  0.126854                               1.0      shorts
# 120  0.775956                               2.0      shorts
# 121  1.000000                               3.0      shorts
# 122  0.956284                               4.0      shorts
# 123  0.841530                               5.0      shorts
# 124  0.127005                               1.0       dress
# 125  0.227941                               2.0       dress
# 126  0.404412                               3.0       dress
# 127  1.000000                               4.0       dress
# 128  0.029240                               1.0       table
# 129  0.251462                               2.0       table
# 130  0.327485                               3.0       table
# 131  1.000000                               4.0       table

# %%
dfheatmap
# Out:
# Length of phoneme sequence shown       1.0       2.0       3.0       4.0  \
# Words
# basketball                        0.094000  0.016279  0.134884  0.246512
# sunglasses                        0.524781  0.093750  0.084821  0.035714
# children                          0.421875  0.458333  0.651042  0.770833
# football                          0.145152  0.063830  0.179331  0.440729
# person                            1.000000  0.117647  0.647059  0.741176
# camera                            0.210526  0.657895  0.973684  1.000000
# jacket                            0.008929  0.401786  0.910714  0.883929
# woman                             0.138249  0.073733  0.700461  0.995392
# shorts                            0.126854  0.775956  1.000000  0.956284
# people                            0.402655  0.469027  0.477876  1.000000
# child                             0.228571  0.746939  0.979592  1.000000
# player                            0.169594  0.448276  0.718391  1.000000
# girls                             0.197674  0.726744  0.837209  1.000000
# dress                             0.127005  0.227941  0.404412  1.000000
# swing                             0.007812  0.043062  0.818182  1.000000
# dogs                              0.029940  0.760479  0.898204  1.000000
# table                             0.029240  0.251462  0.327485  1.000000
# hair                              0.676471  1.000000  0.941176       NaN
# wall                              0.199263  0.573460  1.000000       NaN
# car                               0.543330  1.000000  0.948980       NaN
# head                              0.815789  1.000000  0.894737       NaN
# dog                               0.074055  0.856423  1.000000       NaN
# boys                              0.392000  1.000000  0.955556       NaN
# bike                              0.046237  0.548387  1.000000       NaN
# men                               0.990686  1.000000  0.764706       NaN
# ball                              0.315185  1.000000  0.953704       NaN
# shirt                             0.235616  1.000000  0.908676       NaN
# girl                              0.219745  0.697452  1.000000       NaN
# man                               0.330738  0.914948  1.000000       NaN
# hat                               0.626866  0.746269  1.000000       NaN
# rock                              0.048327  0.928339  1.000000       NaN
# boy                               0.254839  1.000000       NaN       NaN
#
# Length of phoneme sequence shown       5.0       6.0       7.0       8.0  \
# Words
# basketball                        0.551163  0.572093  0.839535  1.000000
# sunglasses                        0.044643  0.120536  0.705357  0.950893
# children                          1.000000  0.921875  0.994792       NaN
# football                          0.887538  1.000000       NaN       NaN
# person                            0.694118       NaN       NaN       NaN
# camera                            0.815789       NaN       NaN       NaN
# jacket                            1.000000       NaN       NaN       NaN
# woman                             1.000000       NaN       NaN       NaN
# shorts                            0.841530       NaN       NaN       NaN
# people                                 NaN       NaN       NaN       NaN
# child                                  NaN       NaN       NaN       NaN
# player                                 NaN       NaN       NaN       NaN
# girls                                  NaN       NaN       NaN       NaN
# dress                                  NaN       NaN       NaN       NaN
# swing                                  NaN       NaN       NaN       NaN
# dogs                                   NaN       NaN       NaN       NaN
# table                                  NaN       NaN       NaN       NaN
# hair                                   NaN       NaN       NaN       NaN
# wall                                   NaN       NaN       NaN       NaN
# car                                    NaN       NaN       NaN       NaN
# head                                   NaN       NaN       NaN       NaN
# dog                                    NaN       NaN       NaN       NaN
# boys                                   NaN       NaN       NaN       NaN
# bike                                   NaN       NaN       NaN       NaN
# men                                    NaN       NaN       NaN       NaN
# ball                                   NaN       NaN       NaN       NaN
# shirt                                  NaN       NaN       NaN       NaN
# girl                                   NaN       NaN       NaN       NaN
# man                                    NaN       NaN       NaN       NaN
# hat                                    NaN       NaN       NaN       NaN
# rock                                   NaN       NaN       NaN       NaN
# boy                                    NaN       NaN       NaN       NaN
#
# Length of phoneme sequence shown       9.0
# Words
# basketball                        0.988372
# sunglasses                        1.000000
# children                               NaN
# football                               NaN
# person                                 NaN
# camera                                 NaN
# jacket                                 NaN
# woman                                  NaN
# shorts                                 NaN
# people                                 NaN
# child                                  NaN
# player                                 NaN
# girls                                  NaN
# dress                                  NaN
# swing                                  NaN
# dogs                                   NaN
# table                                  NaN
# hair                                   NaN
# wall                                   NaN
# car                                    NaN
# head                                   NaN
# dog                                    NaN
# boys                                   NaN
# bike                                   NaN
# men                                    NaN
# ball                                   NaN
# shirt                                  NaN
# girl                                   NaN
# man                                    NaN
# hat                                    NaN
# rock                                   NaN
# boy                                    NaN

# %%
df1
# Out:
#           Word         1         2         3         4         5         6  \
# 21  basketball  0.086000  0.014894  0.123404  0.225532  0.504255  0.523404
# 27  sunglasses  0.244898  0.043750  0.039583  0.016667  0.020833  0.056250
# 11    children  0.180000  0.195556  0.277778  0.328889  0.426667  0.393333
# 26    football  0.106122  0.046667  0.131111  0.322222  0.648889  0.731111
# 10      person  0.184783  0.021739  0.119565  0.136957  0.128261       NaN
# 16      camera  0.044444  0.138889  0.205556  0.211111  0.172222       NaN
# 20      jacket  0.002128  0.095745  0.217021  0.210638  0.238298       NaN
# 4        woman  0.081081  0.043243  0.410811  0.583784  0.586486       NaN
# 29      shorts  0.059524  0.364103  0.469231  0.448718  0.394872       NaN
# 5       people  0.211628  0.246512  0.251163  0.525581       NaN       NaN
# 8        child  0.127273  0.415909  0.545455  0.556818       NaN       NaN
# 19      player  0.064151  0.169565  0.271739  0.378261       NaN       NaN
# 13       girls  0.079070  0.290698  0.334884  0.400000       NaN       NaN
# 30       dress  0.043182  0.077500  0.137500  0.340000       NaN       NaN
# 22       swing  0.004082  0.022500  0.427500  0.522500       NaN       NaN
# 6         dogs  0.020833  0.529167  0.625000  0.695833       NaN       NaN
# 31       table  0.011628  0.100000  0.130233  0.397674       NaN       NaN
# 25        hair  0.053488  0.079070  0.074419       NaN       NaN       NaN
# 24        wall  0.095556  0.275000  0.479545       NaN       NaN       NaN
# 23         car  0.363043  0.668182  0.634091       NaN       NaN       NaN
# 28        head  0.065957  0.080851  0.072340       NaN       NaN       NaN
# 0          dog  0.060000  0.693878  0.810204       NaN       NaN       NaN
# 17        boys  0.072000  0.183673  0.175510       NaN       NaN       NaN
# 14        bike  0.026667  0.316279  0.576744       NaN       NaN       NaN
# 12         men  0.179167  0.180851  0.138298       NaN       NaN       NaN
# 9         ball  0.148000  0.469565  0.447826       NaN       NaN       NaN
# 7        shirt  0.120000  0.509302  0.462791       NaN       NaN       NaN
# 3         girl  0.172500  0.547500  0.785000       NaN       NaN       NaN
# 1          man  0.267347  0.739583  0.808333       NaN       NaN       NaN
# 18         hat  0.105000  0.125000  0.167500       NaN       NaN       NaN
# 15        rock  0.030909  0.593750  0.639583       NaN       NaN       NaN
# 2          boy  0.183721  0.720930       NaN       NaN       NaN       NaN
#
#            7         8         9  Naan
# 21  0.768085  0.914894  0.904255     0
# 27  0.329167  0.443750  0.466667     0
# 11  0.424444       NaN       NaN     2
# 26       NaN       NaN       NaN     3
# 10       NaN       NaN       NaN     4
# 16       NaN       NaN       NaN     4
# 20       NaN       NaN       NaN     4
# 4        NaN       NaN       NaN     4
# 29       NaN       NaN       NaN     4
# 5        NaN       NaN       NaN     5
# 8        NaN       NaN       NaN     5
# 19       NaN       NaN       NaN     5
# 13       NaN       NaN       NaN     5
# 30       NaN       NaN       NaN     5
# 22       NaN       NaN       NaN     5
# 6        NaN       NaN       NaN     5
# 31       NaN       NaN       NaN     5
# 25       NaN       NaN       NaN     6
# 24       NaN       NaN       NaN     6
# 23       NaN       NaN       NaN     6
# 28       NaN       NaN       NaN     6
# 0        NaN       NaN       NaN     6
# 17       NaN       NaN       NaN     6
# 14       NaN       NaN       NaN     6
# 12       NaN       NaN       NaN     6
# 9        NaN       NaN       NaN     6
# 7        NaN       NaN       NaN     6
# 3        NaN       NaN       NaN     6
# 1        NaN       NaN       NaN     6
# 18       NaN       NaN       NaN     6
# 15       NaN       NaN       NaN     6
# 2        NaN       NaN       NaN     7

# %%
scores = []
df1 = df1.drop("Naan",axis=1)
for column in df1.columns[1:]:
    scores.append(sum(df1[column].fillna(0))/(len(df1[column])-sum(df1[column].isna())))

# %%
scores
# Out:
# []

# %%
(len(df1["9"])-sum(df1["9"].isna()))
# Out:
# 2
